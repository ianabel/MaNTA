# %%
# %reload_ext autoreload
# %autoreload 2 

import MaNTA

from Stellarator import StellaratorTransport
# Out:
# Using cache directory: /global/cfs/cdirs/mp217/eatocco/__pycache__
# [CudaDevice(id=0), CudaDevice(id=1), CudaDevice(id=2), CudaDevice(id=3)]

# %%
st_config = {
    "SourceCenter": 0.0,
    "SourceHeight": 30.0,
    "SourceWidth": 0.2,
    "EdgeTemperature":0.5,
    "EdgeDensity": 0.1,
    "n0": 0.5,
}
import time
import datetime

start = time.time()
st = StellaratorTransport(st_config)
# Out:
# Initializing yancc wrapper
# yancc_wrapper initialized successfully.
# INFO: Using default value for configuration option High_Grid_Boundary
# INFO: Using default value for configuration option Lower_Boundary_Fraction
# INFO: Using default value for configuration option Upper_Boundary_Fraction
# INFO: Creating grid with 6 cells from x = 0 to x = 1
# Total HDG degrees of freedom 79
# INFO: Using default value for configuration option Absolute_tolerance
# INFO: Using default value for configuration option tZero
# INFO: Using default value for configuration option MinStepSize
# INFO: Using default value for configuration option OutputPoints
# INFO: Using default value for configuration option SteadyStateTolerance
# INFO: Using default value for configuration option WriteOutput
# Setting initial conditions
# Number of Residual Evaluations due to IDACalcIC 2
# Successfully created StellaratorTransport object
# Configuration done.

# %%
tFinal = 1.0

st.run()

end = time.time()
time_duration = datetime.timedelta(seconds=end-start)
print("Elapsed time:")
print(time_duration)
# Out:
# Writing output at 0.01 ( 15 timesteps )
# Writing output at 0.02 ( 19 timesteps )
# Writing output at 0.03 ( 22 timesteps )
# Writing output at 0.04 ( 24 timesteps )
# Writing output at 0.05 ( 26 timesteps )
# Writing output at 0.06 ( 28 timesteps )
# Writing output at 0.07 ( 30 timesteps )
# Writing output at 0.08 ( 32 timesteps )
# Writing output at 0.09 ( 34 timesteps )
# Writing output at 0.1 ( 35 timesteps )
# Writing output at 0.11 ( 36 timesteps )
# Elapsed time:
# 0:13:00.270161
# Steady State achieved at time t = 0.11
# Total Number of Timesteps             :36
# Total Number of Residual Evaluations  :61
# Total Number of Jacobian Computations :13
# Done.

# %%
import matplotlib.pyplot as plt

# %%
import jax
import jax.numpy as jnp
import equinox as eqx
from functools import partial 

@eqx.filter_custom_jvp
def Objective(field, grid):
    st = 
    return G[0]

@Objective.def_jvp
def Objective_jvp(primals, tangents):
    field, grid = primals
    field_dot, _ = tangents
    G, G_p = st.runAdjointSolve(field = field, grid = grid)   

    field_dot_flatten, _ = jax.flatten_util.ravel_pytree(field_dot)
    gp = jnp.array(G_p['G_p'])
    return G[0], jnp.dot(gp.flatten(), field_dot_flatten)

g = eqx.filter_grad(Objective)

grad_val = g(st.field, st.yancc_wrapper.grid)
B2_mag = st.field.B2mag_fsa
B2_mag_prime= grad_val.B2mag_fsa

plt.plot(B2_mag)
plt.plot(B2_mag_prime)
# Out:
# yancc_wrapper initialized successfully.
# Writing output at 0.21 ( 42 timesteps )
# Steady State achieved at time t = 0.21
# Total Number of Timesteps             :42
# Total Number of Residual Evaluations  :76
# Total Number of Jacobian Computations :19
# Done.
# Computing adjoints
# INFO: Computing adjoints for 5720 parameters
# (5720, 24)
# (5720, 24)
# [0. 0. 0. ... 0. 0. 0.]
# Traced<float64[137280]:JaxprTrace>
