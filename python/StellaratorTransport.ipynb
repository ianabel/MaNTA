# %%
# %reload_ext autoreload
# %autoreload 2 

import MaNTA

from Stellarator import StellaratorTransport
# Out:
# Using cache directory: /global/cfs/cdirs/mp217/eatocco/__pycache__
# [CudaDevice(id=0), CudaDevice(id=1), CudaDevice(id=2), CudaDevice(id=3)]

# %%
st_config = {
    "SourceCenter": 0.0,
    "SourceHeight": 30.0,
    "SourceWidth": 0.2,
    "EdgeTemperature":0.5,
    "EdgeDensity": 0.1,
    "n0": 0.5,
}

st = StellaratorTransport(st_config)
runner = MaNTA.Runner(st)
# Out:
# Initializing yancc wrapper with parameters:
#   nx=5, na=43, nt=17, nz=33
# yancc wrapper initialized successfully.

# %%
config = {
    "OutputFilename": "stellarator",
    "Polynomial_degree": 3,
    "Grid_size": 6,
    "tau": 1.0, 
    "Lower_boundary": 0.0,
    "Upper_boundary": 0.9,
    "Relative_tolerance": 0.01,
    "delta_t": 1e-4,
    "restart": True,
    "solveAdjoint": True, 
}

runner.configure(config)
# Out:
# INFO: Using default value for configuration option RestartFile
# 5721
# computing field
# Total HDG degrees of freedom 79
# INFO: Using default value for configuration option Absolute_tolerance
# INFO: Using default value for configuration option tZero
# INFO: Using default value for configuration option MinStepSize
# INFO: Using default value for configuration option OutputPoints
# INFO: Using default value for configuration option SteadyStateTolerance
# INFO: Using default value for configuration option WriteOutput
# Setting initial conditions
# Evaluating residual at time t=0
# Updating Jacobian at t=0
# Evaluating residual at time t=0
# Updating Jacobian at t=0
# Number of Residual Evaluations due to IDACalcIC 2
# Configuration done.

# %%
tFinal = 1.0
import time
import datetime

start = time.time()
finalState = runner.run_ss()

end = time.time()
time_duration = datetime.timedelta(seconds=end-start)
print("Elapsed time:")
print(time_duration)
# Out:
# Evaluating residual at time t=1e-07
# Updating Jacobian at t=1e-07
# Evaluating residual at time t=2e-07
# Evaluating residual at time t=4e-07
# Evaluating residual at time t=8e-07
# Updating Jacobian at t=8e-07
# Evaluating residual at time t=1.6e-06
# Updating Jacobian at t=1.6e-06
# Evaluating residual at time t=3.2e-06
# Updating Jacobian at t=3.2e-06
# Evaluating residual at time t=6.4e-06
# Updating Jacobian at t=6.4e-06
# Evaluating residual at time t=1.28e-05
# Updating Jacobian at t=1.28e-05
# Evaluating residual at time t=2.56e-05
# Updating Jacobian at t=2.56e-05
# Evaluating residual at time t=5.12e-05
# Updating Jacobian at t=5.12e-05
# Evaluating residual at time t=0.0001024
# Updating Jacobian at t=0.0001024
# Writing output at 0.0001 ( 11 timesteps )
# Elapsed time:
# 0:02:30.105847

# %%
import matplotlib.pyplot as plt

plt.plot(finalState["Variable"])
# Out:
# Steady State achieved at time t = 0.0001
# Total Number of Timesteps             :11
# Total Number of Residual Evaluations  :13
# Total Number of Jacobian Computations :11
# Done.

# %%
G, G_p = runner.runAdjointSolve()
print("Stored energy: " + str(G))

plt.plot(G_p['G_p'])
print(G_p)
# Out:
# Computing adjoints
# INFO: Computing adjoints for 5720 parameters
# (5720, 24)
# computing dGFndp
# np_interal 5720
# Stored energy: 0.5917592375382916
# {'G_p': array([0., 0., 0., ..., 0., 0., 0.], shape=(5720,))}
# finished calculation of adjoints
