# %%
# %reload_ext autoreload
# %autoreload 2 

import MaNTA

from Stellarator import StellaratorTransport
# Out:
# Using cache directory: /global/cfs/cdirs/mp217/eatocco/__pycache__
# [CudaDevice(id=0), CudaDevice(id=1), CudaDevice(id=2), CudaDevice(id=3)]

# %%
st_config = {
    "SourceCenter": 0.0,
    "SourceHeight": 30.0,
    "SourceWidth": 0.2,
    "EdgeTemperature":0.5,
    "EdgeDensity": 0.1,
    "n0": 0.5,
}

st = StellaratorTransport(st_config)
runner = MaNTA.Runner(st)
# Out:
# Initializing yancc wrapper with parameters:
#   nx=5, na=43, nt=17, nz=33
# yancc_wrapper initialized successfully.
# [0.00634337 0.05144305 0.11522362 0.16032329 0.17301004 0.21810971
#  0.28189029 0.32698996 0.33967671 0.38477638 0.44855695 0.49365663
#  0.50634337 0.55144305 0.61522362 0.66032329 0.67301004 0.71810971
#  0.78189029 0.82698996 0.83967671 0.88477638 0.94855695 0.99365663]
# computing field
# INFO: Using default value for configuration option RestartFile
# Total HDG degrees of freedom 79
# INFO: Using default value for configuration option Absolute_tolerance
# INFO: Using default value for configuration option tZero
# INFO: Using default value for configuration option MinStepSize
# INFO: Using default value for configuration option OutputPoints
# INFO: Using default value for configuration option SteadyStateTolerance
# INFO: Using default value for configuration option WriteOutput
# Setting initial conditions
# Configuration done.
# Field(
#   rho=f64[24],
#   theta=f64[24,17],
#   zeta=f64[24,33],
#   wtheta=f64[24,17],
#   wzeta=f64[24,33],
#   B_sup_t=f64[24,17,33],
#   B_sup_z=f64[24,17,33],
#   B_sub_t=f64[24,17,33],
#   B_sub_z=f64[24,17,33],
#   sqrtg=f64[24,17,33],
#   Bmag=f64[24,17,33],
#   bdotgradB=f64[24,17,33],
#   BxgradrhodotgradB=f64[24,17,33],
#   dBdt=f64[24,17,33],
#   dBdz=f64[24,17,33],
#   Bmag_fsa=f64[24],
#   B2mag_fsa=f64[24],
#   psi_r=f64[24],
#   psi_rho=f64[24],
#   Psi=f64[24],
#   R_major=f64[24],
#   a_minor=f64[24],
#   iota=f64[24],
#   B0=f64[24],
#   ntheta=17,
#   nzeta=33,
#   NFP=weak_i64[24]
# )
# 5721
# Field(
#   rho=f64[24],
#   theta=f64[24,17],
#   zeta=f64[24,33],
#   wtheta=f64[24,17],
#   wzeta=f64[24,33],
#   B_sup_t=f64[24,17,33],
#   B_sup_z=f64[24,17,33],
#   B_sub_t=f64[24,17,33],
#   B_sub_z=f64[24,17,33],
#   sqrtg=f64[24,17,33],
#   Bmag=f64[24,17,33],
#   bdotgradB=f64[24,17,33],
#   BxgradrhodotgradB=f64[24,17,33],
#   dBdt=f64[24,17,33],
#   dBdz=f64[24,17,33],
#   Bmag_fsa=f64[24],
#   B2mag_fsa=f64[24],
#   psi_r=f64[24],
#   psi_rho=f64[24],
#   Psi=f64[24],
#   R_major=f64[24],
#   a_minor=f64[24],
#   iota=f64[24],
#   B0=f64[24],
#   ntheta=17,
#   nzeta=33,
#   NFP=weak_i64[24]
# )
# Field(
#   rho=f64[24],
#   theta=f64[24,17],
#   zeta=f64[24,33],
#   wtheta=f64[24,17],
#   wzeta=f64[24,33],
#   B_sup_t=f64[24,17,33],
#   B_sup_z=f64[24,17,33],
#   B_sub_t=f64[24,17,33],
#   B_sub_z=f64[24,17,33],
#   sqrtg=f64[24,17,33],
#   Bmag=f64[24,17,33],
#   bdotgradB=f64[24,17,33],
#   BxgradrhodotgradB=f64[24,17,33],
#   dBdt=f64[24,17,33],
#   dBdz=f64[24,17,33],
#   Bmag_fsa=f64[24],
#   B2mag_fsa=f64[24],
#   psi_r=f64[24],
#   psi_rho=f64[24],
#   Psi=f64[24],
#   R_major=f64[24],
#   a_minor=f64[24],
#   iota=f64[24],
#   B0=f64[24],
#   ntheta=17,
#   nzeta=33,
#   NFP=weak_i64[24]
# )
# Successfully created StellaratorTransport object

# %%
tFinal = 1.0
import time
import datetime

start = time.time()
st.run()

end = time.time()
time_duration = datetime.timedelta(seconds=end-start)
print("Elapsed time:")
print(time_duration)
# Out:
# Evaluating residual at time t=1e-06
# Updating Jacobian at t=1e-06
# Evaluating residual at time t=2e-06
# Evaluating residual at time t=4e-06
# Evaluating residual at time t=8e-06
# Updating Jacobian at t=8e-06
# Evaluating residual at time t=1.6e-05
# Updating Jacobian at t=1.6e-05
# Evaluating residual at time t=3.2e-05
# Updating Jacobian at t=3.2e-05
# Evaluating residual at time t=6.4e-05
# Updating Jacobian at t=6.4e-05
# Evaluating residual at time t=0.000128
# Updating Jacobian at t=0.000128
# Evaluating residual at time t=0.000256
# Updating Jacobian at t=0.000256
# Evaluating residual at time t=0.000512
# Updating Jacobian at t=0.000512
# Evaluating residual at time t=0.001024
# Updating Jacobian at t=0.001024
# Writing output at 0.001 ( 11 timesteps )
# Steady State achieved at time t = 0.001
# Total Number of Timesteps             :11
# Total Number of Residual Evaluations  :11
# Total Number of Jacobian Computations :9
# Done.
#
# 0:16:21.541185

# %%
import matplotlib.pyplot as plt

# %%
G, G_p = st.runAdjointSolve()
print("Stored energy: " + str(G))

plt.plot(G_p['G_p'])
print(G_p)
# Out:
# Computing adjoints
# VmapTracer(aval=float64[], batched=float64[24])
# INFO: Computing adjoints for 5720 parameters
# {'Variable': array([[1.08067395],
#        [1.06454105],
#        [1.01905244],
#        [0.98698364],
#        [0.97415735],
#        [0.93673415],
#        [0.8759347 ],
#        [0.83239151],
#        [0.81895998],
#        [0.77147037],
#        [0.7037354 ],
#        [0.65402124],
#        [0.64056083],
#        [0.59013544],
#        [0.51897013],
#        [0.46755167],
#        [0.45341083],
#        [0.40216373],
#        [0.3296957 ],
#        [0.27819514],
#        [0.26390448],
#        [0.21201971],
#        [0.13858343],
#        [0.08346215]]), 'Derivative': array([[-0.10900754],
#        [-0.58568751],
#        [-0.73674038],
#        [-0.81213109],
#        [-0.83346717],
#        [-0.89189091],
#        [-0.97413198],
#        [-1.015372  ],
#        [-1.02583524],
#        [-1.05446122],
#        [-1.08210525],
#        [-1.1001381 ],
#        [-1.10366148],
#        [-1.11446046],
#        [-1.12736919],
#        [-1.13476535],
#        [-1.13545227],
#        [-1.13522595],
#        [-1.1392459 ],
#        [-1.14075291],
#        [-1.14163558],
#        [-1.14672447],
#        [-1.17306659],
#        [-1.30020511]]), 'Flux': array([[0.03580633],
#        [1.37216488],
#        [3.12163262],
#        [4.18619923],
#        [4.4560756 ],
#        [5.29568491],
#        [6.17461491],
#        [6.60014336],
#        [6.69589117],
#        [6.95962087],
#        [7.18178591],
#        [7.26752057],
#        [7.28432633],
#        [7.32604722],
#        [7.354485  ],
#        [7.36352648],
#        [7.3649404 ],
#        [7.36846417],
#        [7.37051616],
#        [7.37117837],
#        [7.37145684],
#        [7.37136331],
#        [7.37184398],
#        [7.37154283]]), 'Aux': array([], shape=(24, 0), dtype=float64), 'Scalars': array([], dtype=float64)}
# Field(
#   rho=f64[24],
#   theta=f64[24,17],
#   zeta=f64[24,33],
#   wtheta=f64[24,17],
#   wzeta=f64[24,33],
#   B_sup_t=f64[24,17,33],
#   B_sup_z=f64[24,17,33],
#   B_sub_t=f64[24,17,33],
#   B_sub_z=f64[24,17,33],
#   sqrtg=f64[24,17,33],
#   Bmag=f64[24,17,33],
#   bdotgradB=f64[24,17,33],
#   BxgradrhodotgradB=f64[24,17,33],
#   dBdt=f64[24,17,33],
#   dBdz=f64[24,17,33],
#   Bmag_fsa=f64[24],
#   B2mag_fsa=f64[24],
#   psi_r=f64[24],
#   psi_rho=f64[24],
#   Psi=f64[24],
#   R_major=f64[24],
#   a_minor=f64[24],
#   iota=f64[24],
#   B0=f64[24],
#   ntheta=17,
#   nzeta=33,
#   NFP=weak_i64[24]
# )
# GradTracer(primal=VmapTracer(aval=float64[], batched=float64[24]), typeof(tangent)=f64[])
# Field(
#   rho=f64[24],
#   theta=f64[24,17],
#   zeta=f64[24,33],
#   wtheta=f64[24,17],
#   wzeta=f64[24,33],
#   B_sup_t=f64[24,17,33],
#   B_sup_z=f64[24,17,33],
#   B_sub_t=f64[24,17,33],
#   B_sub_z=f64[24,17,33],
#   sqrtg=f64[24,17,33],
#   Bmag=f64[24,17,33],
#   bdotgradB=f64[24,17,33],
#   BxgradrhodotgradB=f64[24,17,33],
#   dBdt=f64[24,17,33],
#   dBdz=f64[24,17,33],
#   Bmag_fsa=f64[24],
#   B2mag_fsa=f64[24],
#   psi_r=f64[24],
#   psi_rho=f64[24],
#   Psi=f64[24],
#   R_major=f64[24],
#   a_minor=f64[24],
#   iota=f64[24],
#   B0=f64[24],
#   ntheta=17,
#   nzeta=33,
#   NFP=None
# )
# (137280,)
# (137280,)
# (5720, 24)
