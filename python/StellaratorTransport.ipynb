# %%
# %reload_ext autoreload
# %autoreload 2 
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"
os.environ["HDF5_USE_FILE_LOCKING"]= "FALSE"
    
import MaNTA
from Objective import (make_objective, make_objective_fd)
from Stellarator import StellaratorTransport

from yancc_wrapper import yancc_data
# Out:
# Using gpu implementation for operation get_solution
# Using gpu implementation for operation run_adjoint_solve
# Using cpu implementation for operation run
# Using cpu implementation for operation run_ss
# Using cache directory: /global/cfs/cdirs/mp217/eatocco/__pycache__
# [CudaDevice(id=0), CudaDevice(id=1), CudaDevice(id=2), CudaDevice(id=3)]

# %%
# # %%
# st_config = {
#     "SourceCenter": 0.0,
#     "SourceHeight": 30.0,
#     "SourceWidth": 0.2,
#     "EdgeTemperature":0.5,
#     "EdgeDensity": 0.1,
#     "n0": 0.5,
# }
# # runner = MaNTA.Runner(st)

# # # %%
# solver_config = {
#     "OutputFilename": "stellarator2",
#     "Polynomial_degree": 3,
#     "Grid_size": 6,
#     "tau": 1.0, 
#     "Lower_boundary": 0.0,
#     "Upper_boundary": 1.0,
#     "Relative_tolerance": 0.01,
#     "delta_t": 0.01,
#     "restart": False,
#     "solveAdjoint": True, 
# }

# config = {
#     "Stellarator": st_config,
#     "Solver": solver_config,
# }

# points =  MaNTA.getNodes(solver_config["Lower_boundary"], solver_config["Upper_boundary"], solver_config["Grid_size"], solver_config["Polynomial_degree"])
# Density = lambda x : (st_config["n0"] - st_config["EdgeDensity"]) * (1 - x*x) + st_config["EdgeDensity"]

# yancc_wrapper = yancc_data.from_eq(points, Density=Density)

# st = StellaratorTransport(config, yancc_wrapper=yancc_wrapper)
# # field_ = st.field
# # grid_ = yancc_wrapper.grid
# vprim_ = st.vprime

# %%
import desc
from desc import set_device
set_device("gpu")

from desc.equilibrium import Equilibrium
from desc.geometry import FourierRZToroidalSurface
from desc.grid import Grid, LinearGrid
from desc.objectives import (
    AspectRatio,
    FixBoundaryR,
    FixBoundaryZ,
    FixCurrent,
    FixPsi,
    ForceBalance,
    LinearObjectiveFromUser,
    ObjectiveFunction,
    ObjectiveFromUser,
    RotationalTransform,
    Volume,
)
from desc.profiles import SplineProfile
from desc.plotting import (
    plot_grid,
    plot_boozer_modes,
    plot_boozer_surface,
    plot_qs_error,
    plot_boundaries,
    plot_boundary,
)
import equinox as eqx
import jax
import jax.numpy as jnp

st_config = {
    "SourceCenter": 0.0,
    "SourceHeight": 250.0,
    "SourceWidth": 0.2,
    "EdgeTemperature":0.1,
    "EdgeDensity": 0.0,
    "n0": 0.5,
}

# # %%
solver_config = {
    "OutputFilename": "stellarator_opt",
    "Polynomial_degree": 3,
    "Grid_size": 6,
    "tau": 100.0, 
    "Lower_boundary": 0.0,
    "Upper_boundary": 0.9,
    "Relative_tolerance": 0.01,
    "delta_t": 0.0001,
    "MinStepSize": 1e-8, 
    "restart": False,
    "solveAdjoint": True, 
}

config = {
    "Stellarator": st_config,
    "Solver": solver_config,
}

Density = lambda x : (st_config["n0"] - st_config["EdgeDensity"]) * (1 - x * x) + st_config["EdgeDensity"]

points =  MaNTA.getNodes(solver_config["Lower_boundary"], solver_config["Upper_boundary"], solver_config["Grid_size"], solver_config["Polynomial_degree"])

yancc_rho = jnp.array(points)
yancc_ntheta = 17
yancc_nzeta = 33

# to allow maximum flexibility to match manta, we use a spline with the same control points as manta \
# + axis and lcfs
# initial pressure is all zeros, can change this if desired
pressure_rho = jnp.concatenate([jnp.zeros(1), yancc_rho, jnp.ones(1)])
desc_pressure = SplineProfile(jnp.zeros_like(pressure_rho), pressure_rho)

eq_est = desc.examples.get("ESTELL")
surf = eq_est.get_surface_at(rho=1)
eq = Equilibrium(M=4, N=4, Psi=0.087, surface=surf, pressure=desc_pressure)
eq = eq.solve(x_scale="ess")[0]
# eq = eq.solve(x_scale="ess")[0]
# # store initial equilibrium for comparison later
eq_init = eq.copy()
# yancc_grid = desc.grid.LinearGrid(rho=yancc_rho, M=eq_init.M_grid, N = eq_init.N_grid, NFP=eq_init.NFP)
# points =  MaNTA.getNodes(solver_config["Lower_boundary"], solver_config["Upper_boundary"], solver_config["Grid_size"], solver_config["Polynomial_degree"])
# yancc_wrapper = yancc_data.from_eq(points, grid = yancc_grid,rho = yancc_rho, Density=Density, eq=eq_init, nt = yancc_ntheta, nz = yancc_nzeta)
yancc_wrapper = yancc_data.from_eq(points, eq=eq_init)

V0 = eq.compute("V")["V"]
# Out:
# /global/u2/e/eatocco/projects/DESC/desc/__init__.py:115: UserWarning: CUDA_VISIBLE_DEVICES= did not match any physical GPU (id=['0', '1', '2', '3']), falling back to CPU
#   warnings.warn(
# Building objective: force
# Precomputing transforms
# Building objective: lcfs R
# Building objective: lcfs Z
# Building objective: fixed Psi
# Building objective: fixed pressure
# Building objective: fixed current
# Building objective: fixed sheet current
# Building objective: self_consistency R
# Building objective: self_consistency Z
# Building objective: lambda gauge
# Building objective: axis R self consistency
# Building objective: axis Z self consistency
# Number of parameters: 120
# Number of objectives: 850
#
# Starting optimization
# Using method: lsq-exact
# Optimization terminated successfully.
# `ftol` condition satisfied. (ftol=1.00e-02)
#          Current function value: 2.817e-05
#          Total delta_x: 4.630e-01
#          Iterations: 7
#          Function evaluations: 8
#          Jacobian evaluations: 8
# ==============================================================================================================
#                                                                  Start  -->   End
# Total (sum of squares):                                      2.754e+00  -->   2.817e-05,
# Maximum absolute Force error:                                5.098e+05  -->   1.015e+03 (N)
# Minimum absolute Force error:                                3.765e+01  -->   2.111e-03 (N)
# Average absolute Force error:                                1.607e+04  -->   6.336e+01 (N)
# Maximum absolute Force error:                                8.432e-01  -->   1.679e-03 (normalized)
# Minimum absolute Force error:                                6.227e-05  -->   3.492e-09 (normalized)
# Average absolute Force error:                                2.659e-02  -->   1.048e-04 (normalized)
# R boundary error:                                            0.000e+00  -->   4.337e-19 (m)
# Z boundary error:                                            0.000e+00  -->   1.788e-18 (m)
# Fixed Psi error:                                             0.000e+00  -->   0.000e+00 (Wb)
# Fixed pressure profile error:                                0.000e+00  -->   0.000e+00 (Pa)
# Fixed current profile error:                                 0.000e+00  -->   0.000e+00 (A)
# Fixed sheet current error:                                   0.000e+00  -->   0.000e+00 (~)
# ==============================================================================================================
#
# Initializing yancc wrapper
# yancc_wrapper initialized successfully.

# %%
import matplotlib.pyplot as plt
import interpax
st = StellaratorTransport(config, yancc_wrapper)

print(st.UpperBoundary(0,0))
print(st.LowerBoundary(0,0))

from State import State
ui = []
ui_p = []
Vp_ui = []
Vp_ui_p = []
for i in range(0, len(points)):
    rho = points[i]
    s = State([st.InitialValue(0, rho)], [st.InitialDerivative(0, rho)], [0], [0], [0])
    Vp_ui.append(s.Variable[0])
    Vp_ui_p.append(s.Derivative[0])
    vp = st.vp[i]
    vpp = st.vpp[i]
    ui.append(st.Vp_u_to_u(0, s, rho, vp, vpp))
    ui_p.append(st.Vp_up_to_up(0, s, rho, vp, vpp))

Vp_ui = jnp.array(Vp_ui)
Vp_ui_p = jnp.array(Vp_ui_p)
vp = jnp.array(vp)
vpp = jnp.array(vpp)

ui_p_formula = Vp_ui_p/vp - vpp * Vp_ui/vp**2

ui_interp = interpax.CubicSpline(points, jnp.array(ui))


plt.figure()
plt.plot(points, ui)
plt.figure()
# plt.plot(points, ui_p_formula)
plt.plot(points, ui_p)
plt.plot(points, ui_interp.derivative()(points))

plt.figure()
plt.plot(points, st.vp)
plt.figure()
plt.plot(points, st.vpp)
# Out:
# configuring
# Successfully created StellaratorTransport object
# 0.03080437103396416
# 0.1942870321521069
# INFO: Using default value for configuration option Grid_points
# INFO: Using default value for configuration option High_Grid_Boundary
# INFO: Using default value for configuration option Lower_Boundary_Fraction
# INFO: Using default value for configuration option Upper_Boundary_Fraction
# INFO: Creating grid with 6 cells from x = 0 to x = 0.9
# Total HDG degrees of freedom 79
# INFO: Using default value for configuration option Absolute_tolerance
# INFO: Using default value for configuration option tZero
# INFO: Using default value for configuration option OutputPoints
# INFO: Using default value for configuration option SteadyStateTolerance
# INFO: Using default value for configuration option useCalcIC
# INFO: Using default value for configuration option WriteOutput
# Configuration done.

# %%
st.run()
# Out:
# Setting initial conditions
# Residual norm at t = 0: -nan
# Residual norm at t = 0: 0

# %%
# import time
# import datetime

# tFinal = 1.0

# start = time.time()

# st.run()

# end = time.time()
# time_duration = datetime.timedelta(seconds=end-start)
# print("Elapsed time:")
# print(time_duration)

# %%
# import matplotlib.pyplot as plt
# u = st.getPressure()

# plt.plot(points, u)

# %%
# @eqx.filter_custom_jvp
# def Objective(fields, grid, yin):
#     yancc_wrapper = yancc_data.from_other(fields, grid, yin)

#     solver_config = {
#         "OutputFilename": "stellarator_opt",
#         "Polynomial_degree": 3,
#         "Grid_size": 6,
#         "tau": 100.0, 
#         "Lower_boundary": 0.0,
#         "Upper_boundary": 0.9,
#         "Relative_tolerance": 0.01,
#         "delta_t": 0.001,
#         "restart": True,
#         "solveAdjoint": True, 
#     }

#     config = {
#         "Stellarator": st_config,
#         "Solver": solver_config,
#     }
#     st = StellaratorTransport(config, yancc_wrapper=yancc_wrapper)
#     st.run()
#     G, G_p = st.runAdjointSolve()

#     pi = jnp.array(st.getPressure())

#     return G[0], pi

# @Objective.def_jvp
# def Objective_jvp(primals, tangents):
#     fields, grid, yin = primals
#     field_dot,_,_ = tangents
#     yancc_wrapper = yancc_data.from_other(fields, grid, yin)

#     solver_config = {
#         "OutputFilename": "stellarator_opt",
#         "Polynomial_degree": 3,
#         "Grid_size": 6,
#         "tau": 100.0, 
#         "Lower_boundary": 0.0,
#         "Upper_boundary": 0.9,
#         "Relative_tolerance": 0.01,
#         "delta_t": 0.001,
#         "restart": True,
#         "solveAdjoint": True, 
#     }

#     config = {
#         "Stellarator": st_config,
#         "Solver": solver_config,
#     }
#     st = StellaratorTransport(config, yancc_wrapper=yancc_wrapper)
#     st.run()
#     G, G_p = st.runAdjointSolve()
#     pi = jnp.array(st.getPressure())
    
#     field_dot_flatten,_ = jax.flatten_util.ravel_pytree(field_dot)

#     return (G[0], pi), (jnp.float32(jnp.dot(G_p.flatten(), field_dot_flatten)), None)

# %%
Objective = make_objective(config)
Objective_fd = make_objective_fd(config)
g = eqx.filter_grad(Objective, has_aux=True)
g_fd = eqx.filter_grad(Objective_fd, has_aux=True)
fields = yancc_wrapper.fields
grid = yancc_wrapper.grid

Vprime = yancc_wrapper.Vprim

g_out = g(fields, grid, Vprime)
g_fd_out = g_fd(fields, grid, Vprime)
# print(g(fields, grid, Vprime))
# Out:
# yancc_wrapper initialized successfully.
# configuring
# Successfully created StellaratorTransport object
# INFO: Using default value for configuration option Grid_points
# INFO: Using default value for configuration option High_Grid_Boundary
# INFO: Using default value for configuration option Lower_Boundary_Fraction
# INFO: Using default value for configuration option Upper_Boundary_Fraction
# INFO: Creating grid with 6 cells from x = 0 to x = 0.9
# Total HDG degrees of freedom 79
# INFO: Using default value for configuration option Absolute_tolerance
# INFO: Using default value for configuration option tZero
# INFO: Using default value for configuration option OutputPoints
# INFO: Using default value for configuration option SteadyStateTolerance
# INFO: Using default value for configuration option useCalcIC
# INFO: Using default value for configuration option WriteOutput
# Configuration done.
# Setting initial conditions
# Residual norm at t = 0: inf
# Residual norm at t = 0: 1.83387e-116
# Residual norm at t = 0: 0
# Residual norm at t = 0: 0.0101113
# Number of Residual Evaluations due to IDACalcIC 3
# Residual norm at t = 0: 0.239519
# Residual norm at t = 1e-07: 0
# Residual norm at t = 1e-07: 3.05952
# Residual norm at t = 4.82307e-08: 0.0706197
# Residual norm at t = 4.82307e-08: 1.56041
# Residual norm at t = 8.54272e-08: 0.0313134
# Residual norm at t = 8.54272e-08: 0.031375
# Residual norm at t = 1.5982e-07: 0.0017921
# Residual norm at t = 1.5982e-07: 0.0641023
# Residual norm at t = 3.08606e-07: 0.0070465
# Residual norm at t = 3.08606e-07: 0.150168
# Residual norm at t = 6.06179e-07: 0.000880614
# Residual norm at t = 6.06179e-07: 0.278289
# Residual norm at t = 9.03751e-07: 0.00288921
# Residual norm at t = 1.4989e-06: 0.14841
# Residual norm at t = 1.4989e-06: 0.3385
# Residual norm at t = 2.09404e-06: 0.00335916
# Residual norm at t = 3.28433e-06: 0.187099
# Residual norm at t = 3.28433e-06: 0.481633
# Residual norm at t = 4.47462e-06: 0.0079437
# Residual norm at t = 5.66491e-06: 0.283456
# Residual norm at t = 8.04549e-06: 0.201061
# Residual norm at t = 8.04549e-06: 0.253833
# Residual norm at t = 1.04261e-05: 0.0161263
# Residual norm at t = 1.51872e-05: 0.0815765
# Residual norm at t = 1.51872e-05: 0.540863
# Residual norm at t = 1.99484e-05: 0.0178592
# Residual norm at t = 2.47095e-05: 0.270039
# Residual norm at t = 2.94707e-05: 0.253137
# Residual norm at t = 3.42319e-05: 0.153577
# Residual norm at t = 3.42319e-05: 0.0687344
# Residual norm at t = 4.37542e-05: 0.00458897
# Residual norm at t = 4.37542e-05: 0.112978
# Residual norm at t = 5.32765e-05: 0.0156047
# Residual norm at t = 6.27988e-05: 0.134413
# Residual norm at t = 7.23211e-05: 0.191141
# Residual norm at t = 9.13657e-05: 0.111759
# Residual norm at t = 9.13657e-05: 1.06498
# Residual norm at t = 0.00011041: 0.0604052
# Residual norm at t = 0.00011041: 1.70574
# Writing output at 0.0001 ( 24 timesteps )
# Residual norm at t = 0.0001: 0.236789
#  dy/dt norm inferred from lambdas is 12.9007
# Residual norm at t = 0.000127551: 0.0387418
# Residual norm at t = 0.000127551: 0.168666
# Residual norm at t = 0.000161831: 0.0558239
# Residual norm at t = 0.000161831: 0.49473
# Residual norm at t = 0.000196111: 0.101353
# Residual norm at t = 0.000230392: 0.457679
# Writing output at 0.0002 ( 28 timesteps )
# Residual norm at t = 0.0002: 3.93469
#  dy/dt norm inferred from lambdas is 8.62858
# Residual norm at t = 0.000264672: 0.832272
# Residual norm at t = 0.000298952: 0.458014
# Residual norm at t = 0.000298952: 0.122903
# Residual norm at t = 0.000333233: 0.0149876
# Writing output at 0.0003 ( 31 timesteps )
# Residual norm at t = 0.0003: 3.50105
#  dy/dt norm inferred from lambdas is 5.80664
# Residual norm at t = 0.000367513: 0.138511
# Residual norm at t = 0.000436074: 0.0281613
# Residual norm at t = 0.000436074: 0.42981
# Writing output at 0.0004 ( 33 timesteps )
# Residual norm at t = 0.0004: 0.20501
# Residual norm at t = 0.000504634: 0.0894309
#  dy/dt norm inferred from lambdas is 3.91597
# Residual norm at t = 0.000504634: 0.20148
# Writing output at 0.0005 ( 34 timesteps )
# Residual norm at t = 0.0005: 0.557991
# Residual norm at t = 0.000573195: 0.0278088
#  dy/dt norm inferred from lambdas is 2.64913
# Residual norm at t = 0.000710316: 0.129971
# Residual norm at t = 0.000710316: 0.445649
# Writing output at 0.0006 ( 36 timesteps )
# Residual norm at t = 0.0006: 0.58975
#  dy/dt norm inferred from lambdas is 1.89
# Writing output at 0.0007 ( 36 timesteps )
# Residual norm at t = 0.0007: 6.8878
#  dy/dt norm inferred from lambdas is 1.21158
# Residual norm at t = 0.000847437: 0.058612
# Writing output at 0.0008 ( 37 timesteps )
# Residual norm at t = 0.0008: 4.16413
#  dy/dt norm inferred from lambdas is 0.783111
# Steady State achieved at time t = 0.0008
# Total Number of Timesteps             :37
# Total Number of Residual Evaluations  :61
# Total Number of Jacobian Computations :13
# Computing adjoints
# INFO: Computing adjoints for 5720 parameters
# (24, 5720)
# (24, 5720)

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

ax.plot(g_out.Bmag_fsa, label="adjoints")
ax.plot(g_fd_out.Bmag_fsa, label="finite_differences")

ax.legend()

fig, ax = plt.subplots()

ax.plot(g_out.sqrtg, label="adjoints")
ax.plot(g_fd_out.sqrtg, label="finite_differences")

ax.legend()
