# %%
# %reload_ext autoreload
# %autoreload 2 
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"
os.environ["HDF5_USE_FILE_LOCKING"]= "FALSE"
    
import MaNTA
from Objective import (make_objective, make_objective_fd)
from Stellarator import StellaratorTransport

from yancc_wrapper import yancc_data

# %%
# # %%
# st_config = {
#     "SourceCenter": 0.0,
#     "SourceHeight": 30.0,
#     "SourceWidth": 0.2,
#     "EdgeTemperature":0.5,
#     "EdgeDensity": 0.1,
#     "n0": 0.5,
# }
# # runner = MaNTA.Runner(st)

# # # %%
# solver_config = {
#     "OutputFilename": "stellarator2",
#     "Polynomial_degree": 3,
#     "Grid_size": 6,
#     "tau": 1.0, 
#     "Lower_boundary": 0.0,
#     "Upper_boundary": 1.0,
#     "Relative_tolerance": 0.01,
#     "delta_t": 0.01,
#     "restart": False,
#     "solveAdjoint": True, 
# }

# config = {
#     "Stellarator": st_config,
#     "Solver": solver_config,
# }

# points =  MaNTA.getNodes(solver_config["Lower_boundary"], solver_config["Upper_boundary"], solver_config["Grid_size"], solver_config["Polynomial_degree"])
# Density = lambda x : (st_config["n0"] - st_config["EdgeDensity"]) * (1 - x*x) + st_config["EdgeDensity"]

# yancc_wrapper = yancc_data.from_eq(points, Density=Density)

# st = StellaratorTransport(config, yancc_wrapper=yancc_wrapper)
# # field_ = st.field
# # grid_ = yancc_wrapper.grid
# vprim_ = st.vprime

# %%
import desc
from desc import set_device
set_device("gpu")

from desc.equilibrium import Equilibrium
from desc.geometry import FourierRZToroidalSurface
from desc.grid import Grid, LinearGrid
from desc.objectives import (
    AspectRatio,
    FixBoundaryR,
    FixBoundaryZ,
    FixCurrent,
    FixPsi,
    ForceBalance,
    LinearObjectiveFromUser,
    ObjectiveFunction,
    ObjectiveFromUser,
    RotationalTransform,
    Volume,
)
from desc.profiles import SplineProfile
from desc.plotting import (
    plot_grid,
    plot_boozer_modes,
    plot_boozer_surface,
    plot_qs_error,
    plot_boundaries,
    plot_boundary,
)
import equinox as eqx
import jax 
import jax.numpy as jnp

st_config = {
    "SourceCenter": 0.2,
    "SourceHeight": 20.0,
    "SourceWidth": 0.4,
    "EdgeTemperature":0.5,
    "EdgeDensity": 0.0,
    "n0": 0.25,
}
# runner = MaNTA.Runner(st)

# # %%
solver_config = {
    "OutputFilename": "stellarator_grad_test",
    "Polynomial_degree": 4, 
    "Grid_size": 4,
    "tau": 1.0, 
    "Lower_boundary": 0.0,
    "Upper_boundary": 0.95,
    "Relative_tolerance": 0.01,
    "Absolute_tolerance": [1e-4],
    "delta_t": 1e-2,
    "MinStepSize": 1e-8,
    "restart": False,
    "solveAdjoint": True,
    "SteadyStateTolerance": 1e-2,
    
}

config = {
    "Stellarator": st_config,
    "Solver": solver_config,
}

points =  MaNTA.getNodes(solver_config["Lower_boundary"], solver_config["Upper_boundary"], solver_config["Grid_size"], solver_config["Polynomial_degree"])

yancc_rho = jnp.array(points)
yancc_ntheta = 17
yancc_nzeta = 33

       
# to allow maximum flexibility to match manta, we use a spline with the same control points as manta \
# + axis and lcfs
# initial pressure is all zeros, can change this if desired
pressure_rho = jnp.concatenate([jnp.zeros(1), yancc_rho, jnp.ones(1)])
desc_pressure = SplineProfile(jnp.zeros_like(pressure_rho), pressure_rho)

eq = desc.examples.get("W7-X")
eq.change_resolution(M=4, N=4,L_grid=len(points), M_grid=4, N_grid=4)
eq = eq.solve(x_scale="ess")[0]
# # eq = eq.solve(x_scale="ess")[0]
# # # store initial equilibrium for comparison later
# eq_init = eq.copy()
# yancc_grid = desc.grid.LinearGrid(rho=yancc_rho, M=eq_init.M_grid, N = eq_init.N_grid, NFP=eq_init.NFP)
# points =  MaNTA.getNodes(solver_config["Lower_boundary"], solver_config["Upper_boundary"], solver_config["Grid_size"], solver_config["Polynomial_degree"])
# yancc_wrapper = yancc_data.from_eq(points, grid = yancc_grid,rho = yancc_rho, Density=Density, eq=eq_init, nt = yancc_ntheta, nz = yancc_nzeta)
nx = 5
na = 43

yancc_wrapper = yancc_data.from_eq(points, eq=eq, nx=nx, na=na)

V0 = eq.compute("V")["V"]
# Out:
# /global/cfs/cdirs/mp217/eatocco/DESC/desc/__init__.py:151: UserWarning: CUDA_VISIBLE_DEVICES= did not match any physical GPU (id=['0', '1', '2', '3']), falling back to CPU
#   warnings.warn(
# Building objective: force
# Precomputing transforms
# Building objective: lcfs R
# Building objective: lcfs Z
# Building objective: fixed Psi
# Building objective: fixed pressure
# Building objective: fixed iota
# Building objective: fixed sheet current
# Building objective: self_consistency R
# Building objective: self_consistency Z
# Building objective: lambda gauge
# Building objective: axis R self consistency
# Building objective: axis Z self consistency
# Number of parameters: 604
# Number of objectives: 594
#
# Starting optimization
# Using method: lsq-exact
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 1.869e-10
#          Total delta_x: 1.202e-01
#          Iterations: 100
#          Function evaluations: 112
#          Jacobian evaluations: 101
# ==============================================================================================================
#                                                                  Start  -->   End
# Total (sum of squares):                                      1.055e-01  -->   1.869e-10,
# Maximum absolute Force error:                                4.015e+07  -->   4.740e+02 (N)
# Minimum absolute Force error:                                9.015e+01  -->   3.423e-01 (N)
# Average absolute Force error:                                9.204e+05  -->   3.932e+01 (N)
# Maximum absolute Force error:                                2.171e-01  -->   2.564e-06 (normalized)
# Minimum absolute Force error:                                4.875e-07  -->   1.851e-09 (normalized)
# Average absolute Force error:                                4.977e-03  -->   2.126e-07 (normalized)
# R boundary error:                                            0.000e+00  -->   2.914e-17 (m)
# Z boundary error:                                            0.000e+00  -->   2.799e-17 (m)
# Fixed Psi error:                                             0.000e+00  -->   0.000e+00 (Wb)
# Fixed pressure profile error:                                0.000e+00  -->   0.000e+00 (Pa)
# Fixed iota profile error:                                    0.000e+00  -->   0.000e+00 (dimensionless)
# Fixed sheet current error:                                   0.000e+00  -->   0.000e+00 (~)
# ==============================================================================================================
#
# Initializing yancc wrapper
# yancc_wrapper initialized successfully.

# %%
# st = StellaratorTransport(config, yancc_wrapper=yancc_wrapper)

# st.run()

# %%
# import time
# import datetime

# tFinal = 1.0

# start = time.time()

# st.run()

# end = time.time()
# time_duration = datetime.timedelta(seconds=end-start)
# print("Elapsed time:")
# print(time_duration)

# %%
# import matplotlib.pyplot as plt
# u = st.getPressure()

# plt.plot(points, u)

# %%
# @eqx.filter_custom_jvp
# def Objective(fields, grid, yin):
#     yancc_wrapper = yancc_data.from_other(fields, grid, yin)

#     solver_config = {
#         "OutputFilename": "stellarator_opt",
#         "Polynomial_degree": 3,
#         "Grid_size": 6,
#         "tau": 100.0, 
#         "Lower_boundary": 0.0,
#         "Upper_boundary": 0.9,
#         "Relative_tolerance": 0.01,
#         "delta_t": 0.001,
#         "restart": True,
#         "solveAdjoint": True, 
#     }

#     config = {
#         "Stellarator": st_config,
#         "Solver": solver_config,
#     }
#     st = StellaratorTransport(config, yancc_wrapper=yancc_wrapper)
#     st.run()
#     G, G_p = st.runAdjointSolve()

#     pi = jnp.array(st.getPressure())

#     return G[0], pi

# @Objective.def_jvp
# def Objective_jvp(primals, tangents):
#     fields, grid, yin = primals
#     field_dot,_,_ = tangents
#     yancc_wrapper = yancc_data.from_other(fields, grid, yin)

#     solver_config = {
#         "OutputFilename": "stellarator_opt",
#         "Polynomial_degree": 3,
#         "Grid_size": 6,
#         "tau": 100.0, 
#         "Lower_boundary": 0.0,
#         "Upper_boundary": 0.9,
#         "Relative_tolerance": 0.01,
#         "delta_t": 0.001,
#         "restart": True,
#         "solveAdjoint": True, 
#     }

#     config = {
#         "Stellarator": st_config,
#         "Solver": solver_config,
#     }
#     st = StellaratorTransport(config, yancc_wrapper=yancc_wrapper)
#     st.run()
#     G, G_p = st.runAdjointSolve()
#     pi = jnp.array(st.getPressure())
    
#     field_dot_flatten,_ = jax.flatten_util.ravel_pytree(field_dot)

#     return (G[0], pi), (jnp.float32(jnp.dot(G_p.flatten(), field_dot_flatten)), None)

# %%
solver_config = {
    "OutputFilename": "stellarator_grad_test",
    "Polynomial_degree": 4, 
    "Grid_size": 4,
    "tau": 1.0, 
    "Lower_boundary": 0.0,
    "Upper_boundary": 0.95,
    "Relative_tolerance": 0.01,
    "Absolute_tolerance": [1e-4],
    "delta_t": 1e-4,
    "MinStepSize": 1e-8,
    "restart": True,
    "solveAdjoint": True,
    "SteadyStateTolerance": 1e-2,
    
}

config = {
    "Stellarator": st_config,
    "Solver": solver_config,
}


# Objective_fd = make_objective_fd(config)
# g = eqx.filter_grad(Objective, has_aux=True)
# g_fd = eqx.filter_grad(Objective_fd, has_aux=True)
# fields = yancc_wrapper.fields
# grid = yancc_wrapper.grid

# Vprime = yancc_wrapper.Vprim

# # g_fd_out = g_fd((fields,Vprime), grid)
# g_out = g((fields, Vprime), grid)

# # print(g(fields, grid, Vprime))

# %%
# import matplotlib.pyplot as plt

# fig, ax = plt.subplots()

# (field_grad, dvp), pressure = g_out
# ax.plot(dvp, label="adjoints")
# # ax.plot(g_fd_out.Bmag_fsa, label="finite_differences")

# ax.legend()

# fig, ax = plt.subplots()

# ax.plot(jnp.sum(field_grad.sqrtg, axis=2))
# ax.plot(g_fd_out.sqrtg, label="finite_differences")

# %%
import yancc
yancc_desc_grid = LinearGrid(
    rho=yancc_wrapper.rho, theta=yancc_ntheta, zeta=yancc_nzeta, NFP=eq.NFP
)
manta_objective = make_objective(config)

def objective_from_user_fun(grid, data):
  # note: don't change the signature to this function
    yancc_dat = {
        "B_sup_t": data["B^theta"],
        "B_sup_z": data["B^zeta"],
        "B_sub_t": data["B_theta"],
        "B_sub_z": data["B_zeta"],
        "Bmag": data["|B|"],
        "dBdt": data["|B|_t"],
        "dBdz": data["|B|_z"],
        "sqrtg": data["sqrt(g)"],
    }

    yancc_dat = {
        key: grid.meshgrid_reshape(val, "rtz") for key, val in yancc_dat.items()
    }

    yancc_dat["Psi"] = grid.compress(
        data["Psi"] / grid.nodes[:, 0] ** 2, surface_label="rho"
    )
    yancc_dat["a_minor"] = jnp.full(grid.num_rho, data["a"])
    yancc_dat["R_major"] = jnp.full(grid.num_rho, data["R0"])
    yancc_dat["iota"] = grid.compress(data["iota"], surface_label="rho")
    yancc_dat["rho"] = grid.compress(grid.nodes[:, 0], surface_label="rho")

    V = grid.compress(data['V(r)'])
    V_r = grid.compress(data['V_r(r)'])
    Vprime = V_r/V[-1]
    
    fields = jax.vmap(lambda d: yancc.field.Field(**d, NFP=grid.NFP))(yancc_dat)

    desc_pressure = grid.compress(data["p"], surface_label="rho")
    
    stored_energy, manta_pressure = manta_objective((fields, Vprime), grid)
    print("------------ STORED ENERGY ----------------")
    print(stored_energy)
    print("-------------------------------------------")
    
    pressure_error = desc_pressure - manta_pressure

    print("------------TOTAL PRESSURE ERROR-----------")
    print(pressure_error)
    print("-------------------------------------------")

    # optimization is easiest for least squares objectives, so instead of maximizing
    # stored energy we minimize 1/stored_energy^2 (the squaring happens later)
    return jnp.append(pressure_error, 1 / stored_energy)

pressure_error_weight = jnp.full(yancc_desc_grid.num_rho, 0.0)
stored_energy_weight = 100.0
objective_from_user_weight = jnp.append(pressure_error_weight, stored_energy_weight)

objectives = [
ObjectiveFromUser(
    objective_from_user_fun,
    eq,
    target=0,
    weight=objective_from_user_weight,
    grid=yancc_desc_grid,
    deriv_mode="fwd", 
    # need this assuming manta only has vjp, if using jvp switch to fwd
)
]

objfun = ObjectiveFunction(objectives)
objfun.build(use_jit=False)
J = 0
with jax.default_device(jax.devices('cpu')[0]):
    J = objfun.jac_scaled(objfun.x(eq))
    print(J)
# Out:
# Building objective: Custom
# yancc_wrapper initialized successfully.
# configuring
# Successfully created StellaratorTransport object
# ------------ STORED ENERGY ----------------
# JitTracer(float32[])
# -------------------------------------------
# ------------TOTAL PRESSURE ERROR-----------
# JitTracer(float64[20])
# -------------------------------------------
# Total HDG degrees of freedom 65
# Configuration done.
# yancc_wrapper initialized successfully.
# configuring
# Successfully created StellaratorTransport object
# Total HDG degrees of freedom 65
# Configuration done.
# Setting initial conditions
# Residual norm at t = 0: 0
# Residual norm at t = 0: 6.08464e+103
# Residual norm at t = 0: 0
# Residual norm at t = 0: 0.0270467
# Number of Residual Evaluations due to IDACalcIC 3
# Residual norm at t = 0: 0.129148
# Residual norm at t = 0.0001: -nan
# Writing output at 0.0001 ( 1 timesteps )
# Residual norm at t = 0.0001: 0.129114
#  dy/dt norm inferred from lambdas is 0.0080064
# Steady State achieved at time t = 0.0001
# Total Number of Timesteps             :1
# Total Number of Residual Evaluations  :4
# Total Number of Jacobian Computations :3
# Computing adjoints
# INFO: Computing adjoints for 5721 parameters
# (Field(
#   rho=f64[20],
#   theta=f64[20,17],
#   zeta=f64[20,33],
#   wtheta=f64[20,17],
#   wzeta=f64[20,33],
#   B_sup_t=f64[20,17,33],
#   B_sup_z=f64[20,17,33],
#   B_sub_t=f64[20,17,33],
#   B_sub_z=f64[20,17,33],
#   sqrtg=f64[20,17,33],
#   Bmag=f64[20,17,33],
#   bdotgradB=f64[20,17,33],
#   BxgradrhodotgradB=f64[20,17,33],
#   dBdt=f64[20,17,33],
#   dBdz=f64[20,17,33],
#   Bmag_fsa=f64[20],
#   B2mag_fsa=f64[20],
#   psi_r=f64[20],
#   psi_rho=f64[20],
#   Psi=f64[20],
#   R_major=f64[20],
#   a_minor=f64[20],
#   iota=f64[20],
#   B0=f64[20],
#   ntheta=17,
#   nzeta=33,
#   NFP=None
# ), Array([ -0.23645931,  -3.44751123,  -5.91354732,  -7.75591901,
#         -8.72688026,  -8.9699566 ,  -9.80978545, -10.97156245,
#        -11.90144346, -12.36469888, -12.4754318 , -12.83575519,
#        -13.25771811, -13.49828768, -13.56694006, -13.5757785 ,
#        -13.57976139, -13.4928457 , -13.31750328, -13.17275062],      dtype=float64))
# (20, 5721)
# (20, 5721)
# Successfully computed dgdp
# 5721
# 20
# Done.
# ---------------------------------------------------------------------------
# JaxRuntimeError                           Traceback (most recent call last)
# Cell In[23], line 75
#      73 J = 0
#      74 with jax.default_device(jax.devices('cpu')[0]):
# ---> 75     J = objfun.jac_scaled(objfun.x(eq))
#      76     print(J)
#
# File /global/cfs/cdirs/mp217/eatocco/DESC/desc/objectives/objective_funs.py:838, in ObjectiveFunction.jac_scaled(self, x, constants)
#     836 """Compute Jacobian matrix of self.compute_scaled wrt x."""
#     837 v = jnp.eye(x.shape[0])
# --> 838 return self.jvp_scaled(v, x, constants).T
#
# File /global/cfs/cdirs/mp217/eatocco/DESC/desc/objectives/objective_funs.py:923, in ObjectiveFunction.jvp_scaled(self, v, x, constants)
#     909 """Compute Jacobian-vector product of self.compute_scaled.
#     910
#     911 Parameters
#    (...)    920
#     921 """
#     922 if self._deriv_mode == "batched":
# --> 923     J = self._jvp_batched(v, x, constants, "scaled")
#     924 if self._deriv_mode == "blocked":
#     925     J = self._jvp_blocked(v, x, constants, "scaled")
#
# File /global/cfs/cdirs/mp217/eatocco/DESC/desc/objectives/objective_funs.py:887, in ObjectiveFunction._jvp_batched(self, v, x, constants, op)
#     885 if len(v) == 1:
#     886     jvpfun = lambda dx: Derivative.compute_jvp(fun, 0, dx, x)
# --> 887     return batched_vectorize(
#     888         jvpfun, signature="(n)->(k)", chunk_size=self._jac_chunk_size
#     889     )(v[0])
#     890 elif len(v) == 2:
#     891     jvpfun = lambda dx1, dx2: Derivative.compute_jvp2(fun, 0, 0, dx1, dx2, x)
#
# File /global/cfs/cdirs/mp217/eatocco/DESC/desc/batching.py:400, in batched_vectorize.<locals>.wrapped(*args, **kwargs)
#     396     else:
#     397         vectorized_func = vmap_chunked(
#     398             vectorized_func, in_axes, chunk_size=chunk_size
#     399         )
# --> 400 result = vectorized_func(*squeezed_args)
#     402 if not dims_to_expand:
#     403     return result
#
# File /global/cfs/cdirs/mp217/eatocco/DESC/desc/batching.py:145, in _evaluate_in_chunks(vmapped_fun, chunk_size, argnums, reduction, chunk_reduction, *args, **kwargs)
#     143 n_elements = tree_leaves(args[argnums[0]])[0].shape[0]
#     144 if n_elements <= chunk_size:
# --> 145     return chunk_reduction(vmapped_fun(*args, **kwargs))
#     147 scan_x, remain_x = zip(
#     148     *[
#     149         _batch_and_remainder(a, chunk_size) if i in argnums else (a, a)
#     150         for i, a in enumerate(args)
#     151     ]
#     152 )
#     153 # Note that num_batches in _batch_and_remainder is always positive.
#
#     [... skipping hidden 6 frame]
#
# File ~/.conda/envs/desc-env/lib/python3.12/site-packages/jax/_src/numpy/vectorize.py:144, in _check_output_dims.<locals>.wrapped(*args)
#     143 def wrapped(*args):
# --> 144   out = func(*args)
#     145   out_shapes = list(map(np.shape, out if isinstance(out, tuple) else [out]))  # pyrefly redefined builtin
#     147   output_core_dims = expected_output_core_dims
#
# File /global/cfs/cdirs/mp217/eatocco/DESC/desc/objectives/objective_funs.py:886, in ObjectiveFunction._jvp_batched.<locals>.<lambda>(dx)
#     884 fun = lambda x: getattr(self, "compute_" + op)(x, constants)
#     885 if len(v) == 1:
# --> 886     jvpfun = lambda dx: Derivative.compute_jvp(fun, 0, dx, x)
#     887     return batched_vectorize(
#     888         jvpfun, signature="(n)->(k)", chunk_size=self._jac_chunk_size
#     889     )(v[0])
#     890 elif len(v) == 2:
#
# File /global/cfs/cdirs/mp217/eatocco/DESC/desc/derivatives.py:218, in AutoDiffDerivative.compute_jvp(cls, fun, argnum, v, *args, **kwargs)
#     215         _args[i] = xi
#     216     return fun(*_args, **kwargs)
# --> 218 y, u = jax.jvp(_fun, tuple(args[i] for i in argnum), v)
#     219 return u
#
#     [... skipping hidden 7 frame]
#
# File /global/cfs/cdirs/mp217/eatocco/DESC/desc/derivatives.py:216, in AutoDiffDerivative.compute_jvp.<locals>._fun(*x)
#     214 for i, xi in zip(argnum, x):
#     215     _args[i] = xi
# --> 216 return fun(*_args, **kwargs)
#
# File /global/cfs/cdirs/mp217/eatocco/DESC/desc/objectives/objective_funs.py:884, in ObjectiveFunction._jvp_batched.<locals>.<lambda>(x)
#     881 def _jvp_batched(self, v, x, constants=None, op="scaled"):
#     882     v = ensure_tuple(v)
# --> 884     fun = lambda x: getattr(self, "compute_" + op)(x, constants)
#     885     if len(v) == 1:
#     886         jvpfun = lambda dx: Derivative.compute_jvp(fun, 0, dx, x)
#
# File /global/cfs/cdirs/mp217/eatocco/DESC/desc/objectives/objective_funs.py:644, in ObjectiveFunction.compute_scaled(self, x, constants)
#     628 """Compute the objective function and apply weighting and normalization.
#     629
#     630 Parameters
#    (...)    641
#     642 """
#     643 op = "compute_scaled"
# --> 644 return self._compute_op(x, constants=constants, op=op)
#
# File /global/cfs/cdirs/mp217/eatocco/DESC/desc/objectives/objective_funs.py:600, in ObjectiveFunction._compute_op(self, x, constants, op)
#     596 params = self.unpack_state(x)
#     597 assert len(params) == len(constants) == len(self.objectives)
#     598 f = jnp.concatenate(
#     599     [
# --> 600         getattr(obj, op)(*par, constants=const)
#     601         for par, obj, const in zip(params, self.objectives, constants)
#     602     ]
#     603 )
#     604 return f
#
# File /global/cfs/cdirs/mp217/eatocco/DESC/desc/objectives/objective_funs.py:1400, in _Objective.compute_scaled(self, *args, **kwargs)
#    1398 """Compute and apply weighting and normalization."""
#    1399 args = self._maybe_array_to_params(*args)
# -> 1400 f = self.compute(*args, **kwargs)
#    1401 if self._loss_function is not None:
#    1402     f = self._loss_function(f)
#
# File /global/cfs/cdirs/mp217/eatocco/DESC/desc/objectives/_generic.py:684, in ObjectiveFromUser.compute(self, params, constants)
#     675     constants = self.constants
#     676 data = compute_fun(
#     677     self._p,
#     678     self._data_keys,
#    (...)    682     **self._compute_kwargs,
#     683 )
# --> 684 f = self._fun_wrapped(data)
#     685 return f
#
# File /global/cfs/cdirs/mp217/eatocco/DESC/desc/objectives/_generic.py:641, in ObjectiveFromUser.build.<locals>.<lambda>(data)
#     636     else:
#     637         dummy_data[key] = jnp.empty(
#     638             (grid.num_nodes, data_index[self._p][key]["dim"])
#     639         ).squeeze()
# --> 641 self._fun_wrapped = lambda data: self._fun(grid, data)
#     643 self._dim_f = jax.eval_shape(self._fun_wrapped, dummy_data).size
#     644 self._scalar = self._dim_f == 1
#
# Cell In[23], line 40, in objective_from_user_fun(grid, data)
#      36 fields = jax.vmap(lambda d: yancc.field.Field(**d, NFP=grid.NFP))(yancc_dat)
#      38 desc_pressure = grid.compress(data["p"], surface_label="rho")
# ---> 40 stored_energy, manta_pressure = manta_objective((fields, Vprime), grid)
#      41 print("------------ STORED ENERGY ----------------")
#      42 print(stored_energy)
#
#     [... skipping hidden 10 frame]
#
# File /global/u2/e/eatocco/projects/MaNTA/python/Objective.py:70, in make_objective.<locals>._objective_base_jvp(primals, tangents)
#      67 (field_dot, Vp_dot), _= tangents
#      69 yancc_wrapper = yancc_data.from_fields(fields, grid, Vp)
# ---> 70 G, G_p, pi = _f_wrapped(yancc_wrapper)
#      71 # _, unflatten = jax.flatten_util.ravel_pytree(fields)
#      73 _, unflatten_field = jax.flatten_util.ravel_pytree(yancc_wrapper.fields_unstacked[0])
#
# File /global/u2/e/eatocco/projects/MaNTA/python/Objective.py:35, in make_objective.<locals>.StellaratorFun(config, yin)
#      33 st = StellaratorTransport(config, yancc_wrapper=yin)
#      34 st.run()
# ---> 35 G, G_p = st.getAdjointGradients()
#      37 pi = jnp.array(st.getPressure())
#      39 return G[0], G_p, pi
#
# File /global/u2/e/eatocco/projects/MaNTA/python/Stellarator.py:181, in StellaratorTransport.getAdjointGradients(self)
#     180 def getAdjointGradients(self):
# --> 181     G, G_p = self.runner.Get_adjoint_gradients()
#     182     return G, G_p
#
# File /global/u2/e/eatocco/projects/MaNTA/python/FFIRunner.py:77, in FFIRunner.Get_adjoint_gradients(self)
#      76 def Get_adjoint_gradients(self):
# ---> 77     return jax.ffi.ffi_call(ffi_ops["get_adjoint_gradients"], self.adjoint_output)(obj=self.get_address())
#
# File ~/.conda/envs/desc-env/lib/python3.12/site-packages/jax/_src/ffi.py:563, in ffi_call.<locals>.wrapped(*args, **kwargs)
#     561     static_input_output_aliases.append((i_idx, o_idx))
#     562 args = core.standard_insert_pvary(*args)
# --> 563 results = ffi_call_p.bind(
#     564     *args,
#     565     result_avals=result_avals,
#     566     vmap_method=vmap_method,
#     567     target_name=target_name,
#     568     has_side_effect=has_side_effect,
#     569     input_layouts=static_input_layouts,
#     570     output_layouts=static_output_layouts,
#     571     input_output_aliases=tuple(static_input_output_aliases),
#     572     custom_call_api_version=custom_call_api_version,
#     573     legacy_backend_config=legacy_backend_config,
#     574     attributes=_wrap_kwargs_hashable(kwargs),
#     575 )
#     576 if multiple_results:
#     577   if isinstance(result_shape_dtypes, tuple):
#
#     [... skipping hidden 24 frame]
#
# File ~/.conda/envs/desc-env/lib/python3.12/site-packages/jax/_src/compiler.py:362, in backend_compile_and_load(backend, module, executable_devices, options, host_callbacks)
#     353       return backend.compile_and_load(
#     354           module,
#     355           executable_devices=executable_devices,
#     356           compile_options=options,
#     357           host_callbacks=host_callbacks,
#     358       )
#     359     # Some backends don't have `host_callbacks` option yet
#     360     # TODO(sharadmv): remove this fallback when all backends allow `compile`
#     361     # to take in `host_callbacks`
# --> 362     return backend.compile_and_load(
#     363         module,
#     364         executable_devices=executable_devices,
#     365         compile_options=options,
#     366     )
#     367 except _jax.JaxRuntimeError as e:
#     368   for error_handler in _XLA_RUNTIME_ERROR_HANDLERS:
#
# JaxRuntimeError: NOT_FOUND: No FFI handler registered for get_adjoint_gradients_ffi_cuda on a platform Host (canonical host)
