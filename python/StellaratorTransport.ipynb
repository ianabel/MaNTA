# %%
# %reload_ext autoreload
# %autoreload 2

import MaNTA

from Stellarator import StellaratorTransport

# %%
st_config = {
    "SourceCenter": 0.05,
    "SourceHeight": 35.0,
    "SourceWidth": 0.2,
    "EdgeTemperature":0.5,
    "EdgeDensity": 0.1,
    "n0": 0.5,
}

st = StellaratorTransport(st_config)
runner = MaNTA.Runner(st)
# Out:
# Initializing yancc wrapper with parameters:
#   nx=5, na=65, nt=17, nz=33
# yancc wrapper initialized successfully.

# %%
config = {
    "OutputFilename": "stellarator",
    "Polynomial_degree": 4,
    "Grid_size": 3,
    "tau": 1.0, 
    "Lower_boundary": 0.0,
    "Upper_boundary": 0.9,
    "Relative_tolerance": 0.01,
    "tFinal": 1.0,
    "delta_t": 0.5,
    "restart": True,
}

runner.configure(config)
# Out:
# INFO: Using default value for configuration option RestartFile
# INFO: Using default value for configuration option solveAdjoint
# Total HDG degrees of freedom 49
# INFO: Using default value for configuration option Absolute_tolerance
# INFO: Using default value for configuration option tZero
# INFO: Using default value for configuration option MinStepSize
# INFO: Using default value for configuration option OutputPoints

# %%
runner.run()
# Out:
# Setting initial conditions
# Evaluating residual
#   current residual norm: 2.35051e-159
# Evaluating residual
#   current residual norm: inf
# Updating Jacobian at time 0
# Evaluating residual
#   current residual norm: inf
# Evaluating residual
#   current residual norm: 0.0049116
# Updating Jacobian at time 0
# Number of Residual Evaluations due to IDACalcIC 3
# Evaluating residual
#   current residual norm: 0.000167857
# Evaluating residual
#   current residual norm: inf
# Updating Jacobian at time 0.0005
# Evaluating residual
#   current residual norm: 0.768117
# Evaluating residual
#   current residual norm: 0.0599231
# Evaluating residual
#   current residual norm: 0.165777
# Evaluating residual
#   current residual norm: 0.457098
# Evaluating residual
#   current residual norm: 0.072235
# Updating Jacobian at time 0.004
# Evaluating residual
#   current residual norm: 0.867286
# Evaluating residual
#   current residual norm: 0.0979225
# Evaluating residual
#   current residual norm: 0.324364
# Evaluating residual
#   current residual norm: 0.0590243
# Evaluating residual
#   current residual norm: 0.237117
# Updating Jacobian at time 0.0112
# Evaluating residual
#   current residual norm: 0.593934
# Evaluating residual
#   current residual norm: 0.0588138
# Evaluating residual
#   current residual norm: 0.364972
# Evaluating residual
#   current residual norm: 0.269773
# Updating Jacobian at time 0.0256
# Evaluating residual
#   current residual norm: 0.840018
# Evaluating residual
#   current residual norm: 0.0801909
# Evaluating residual
#   current residual norm: 0.616792
# Evaluating residual
#   current residual norm: 0.43635
# Evaluating residual
#   current residual norm: 0.306644
# Updating Jacobian at time 0.0616
# Evaluating residual
#   current residual norm: 0.801733
# Evaluating residual
#   current residual norm: 0.049805
# Evaluating residual
#   current residual norm: 0.43813
# Evaluating residual
#   current residual norm: 0.229294
# Updating Jacobian at time 0.1192
# Evaluating residual
#   current residual norm: 0.35176
# Evaluating residual
#   current residual norm: 0.0249456
# Evaluating residual
#   current residual norm: 0.136965
# Updating Jacobian at time 0.2056
# Evaluating residual
#   current residual norm: 0.131126
# Evaluating residual
#   current residual norm: 0.0145531
# Updating Jacobian at time 0.3208
# Evaluating residual
#   current residual norm: 0.060908
# Evaluating residual
#   current residual norm: 0.00255034
# Updating Jacobian at time 0.5512
# Writing output at 0.5 ( 21 timesteps )
# Evaluating residual
#   current residual norm: 0.000167857
# Evaluating residual
#   current residual norm: 0.0130736
# Updating Jacobian at time 1.012
# Writing output at 1 ( 22 timesteps )
# Evaluating residual
#   current residual norm: 0.000197079
# Evaluating residual
#   current residual norm: 0.00763621
# Updating Jacobian at time 1.9336
# Writing output at 1.5 ( 23 timesteps )
# Evaluating residual
#   current residual norm: 0.000371565
# Evaluating residual
#   current residual norm: 0.00646928
# Updating Jacobian at time 3.7768
# Writing output at 2 ( 24 timesteps )
# Evaluating residual
#   current residual norm: 0.000286717
# Total Number of Timesteps             :24
# Total Number of Residual Evaluations  :37
# Total Number of Jacobian Computations :14
# 0
# Done.
