# %%
# %reload_ext autoreload
# %autoreload 2

import MaNTA

from Stellarator import StellaratorTransport

# %%
st_config = {
    "SourceCenter": 0.05,
    "SourceHeight": 35.0,
    "SourceWidth": 0.2,
    "EdgeTemperature":0.5,
    "EdgeDensity": 0.1,
    "n0": 0.5,
}

st = StellaratorTransport(st_config)
runner = MaNTA.Runner(st)
# Out:
# Initializing yancc wrapper with parameters:
#   nx=5, na=45, nt=17, nz=33
# yancc wrapper initialized successfully.

# %%
config = {
    "OutputFilename": "stellarator",
    "Polynomial_degree": 4,
    "Grid_size": 4,
    "tau": 1.0, 
    "Lower_boundary": 0.0,
    "Upper_boundary": 0.9,
    "Relative_tolerance": 0.01,
    "tFinal": 1.0,
    "delta_t": 0.5,
    "restart": False,
}

runner.configure(config)
# Out:
# INFO: Using default value for configuration option High_Grid_Boundary
# INFO: Using default value for configuration option Lower_Boundary_Fraction
# INFO: Using default value for configuration option Upper_Boundary_Fraction
# INFO: Creating grid with 4 cells from x = 0 to x = 0.9
# INFO: Using default value for configuration option solveAdjoint
# Total HDG degrees of freedom 65
# INFO: Using default value for configuration option Absolute_tolerance
# INFO: Using default value for configuration option tZero
# INFO: Using default value for configuration option MinStepSize
# INFO: Using default value for configuration option OutputPoints

# %%
import time
start = time.time()
runner.run()

end = time.time()

print("Elapsed time:")
print(end - start)
# Out:
# Setting initial conditions
# computing field
# Evaluating residual
#   current residual norm: -nan
# Evaluating residual
#   current residual norm: -nan
# Updating Jacobian at time 0
# W0227 16:54:25.248189 1243044 bfc_allocator.cc:501] Allocator (GPU_0_bfc) ran out of memory trying to allocate 14.41GiB (rounded to 15470569728)requested by op
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# W0227 16:54:25.251110 1243044 bfc_allocator.cc:512] *________***______***__***__*_**_***____________****_*****__________________________________________
# E0227 16:54:25.251997 1243044 pjrt_stream_executor_client.cc:3314] Execution of replica 0 failed: RESOURCE_EXHAUSTED: Out of memory while trying to allocate 15470569664 bytes. [tf-allocator-allocation-error='']
# ---------------------------------------------------------------------------
# JaxStackTraceBeforeTransformation         Traceback (most recent call last)
# File ~/.conda/envs/desc-env/lib/python3.12/runpy.py:198, in _run_module_as_main()
#     197     sys.argv[0] = mod_spec.origin
# --> 198 return _run_code(code, main_globals, None,
#     199                  "__main__", mod_spec)
#
# File ~/.conda/envs/desc-env/lib/python3.12/runpy.py:88, in _run_code()
#      81 run_globals.update(__name__ = mod_name,
#      82                    __file__ = fname,
#      83                    __cached__ = cached,
#    (...)     86                    __package__ = pkg_name,
#      87                    __spec__ = mod_spec)
# ---> 88 exec(code, run_globals)
#      89 return run_globals
#
# File ~/.conda/envs/desc-env/lib/python3.12/site-packages/ipykernel_launcher.py:18
#      16 from ipykernel import kernelapp as app
# ---> 18 app.launch_new_instance()
#
# File ~/.conda/envs/desc-env/lib/python3.12/site-packages/traitlets/config/application.py:1075, in launch_instance()
#    1074 app.initialize(argv)
# -> 1075 app.start()
#
# File ~/.conda/envs/desc-env/lib/python3.12/site-packages/ipykernel/kernelapp.py:758, in start()
#     757 try:
# --> 758     self.io_loop.start()
#     759 except KeyboardInterrupt:
#
# File ~/.conda/envs/desc-env/lib/python3.12/site-packages/tornado/platform/asyncio.py:211, in start()
#     210 def start(self) -> None:
# --> 211     self.asyncio_loop.run_forever()
#
# File ~/.conda/envs/desc-env/lib/python3.12/asyncio/base_events.py:645, in run_forever()
#     644 while True:
# --> 645     self._run_once()
#     646     if self._stopping:
#
# File ~/.conda/envs/desc-env/lib/python3.12/asyncio/base_events.py:1999, in _run_once()
#    1998     else:
# -> 1999         handle._run()
#    2000 handle = None
#
# File ~/.conda/envs/desc-env/lib/python3.12/asyncio/events.py:88, in _run()
#      87 try:
# ---> 88     self._context.run(self._callback, *self._args)
#      89 except (SystemExit, KeyboardInterrupt):
#
# File ~/.conda/envs/desc-env/lib/python3.12/site-packages/ipykernel/kernelbase.py:621, in shell_main()
#     620 async with asyncio_lock:
# --> 621     await self.dispatch_shell(msg, subshell_id=subshell_id)
#
# File ~/.conda/envs/desc-env/lib/python3.12/site-packages/ipykernel/kernelbase.py:478, in dispatch_shell()
#     477     if inspect.isawaitable(result):
# --> 478         await result
#     479 except Exception:
#
# File ~/.conda/envs/desc-env/lib/python3.12/site-packages/ipykernel/ipkernel.py:372, in execute_request()
#     371 """Override for cell output - cell reconciliation."""
# --> 372 await super().execute_request(stream, ident, parent)
#
# File ~/.conda/envs/desc-env/lib/python3.12/site-packages/ipykernel/kernelbase.py:834, in execute_request()
#     833 if inspect.isawaitable(reply_content):
# --> 834     reply_content = await reply_content
#     835 else:
#
# File ~/.conda/envs/desc-env/lib/python3.12/site-packages/ipykernel/ipkernel.py:464, in do_execute()
#     463 if accepts_params["cell_id"]:
# --> 464     res = shell.run_cell(
#     465         code,
#     466         store_history=store_history,
#     467         silent=silent,
#     468         cell_id=cell_id,
#     469     )
#     470 else:
#
# File ~/.conda/envs/desc-env/lib/python3.12/site-packages/ipykernel/zmqshell.py:663, in run_cell()
#     662 self._last_traceback = None
# --> 663 return super().run_cell(*args, **kwargs)
#
# File ~/.conda/envs/desc-env/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3123, in run_cell()
#    3122 try:
# -> 3123     result = self._run_cell(
#    3124         raw_cell, store_history, silent, shell_futures, cell_id
#    3125     )
#    3126 finally:
#
# File ~/.conda/envs/desc-env/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3178, in _run_cell()
#    3177 try:
# -> 3178     result = runner(coro)
#    3179 except BaseException as e:
#
# File ~/.conda/envs/desc-env/lib/python3.12/site-packages/IPython/core/async_helpers.py:128, in _pseudo_sync_runner()
#     127 try:
# --> 128     coro.send(None)
#     129 except StopIteration as exc:
#
# File ~/.conda/envs/desc-env/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3400, in run_cell_async()
#    3397 interactivity = "none" if silent else self.ast_node_interactivity
# -> 3400 has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    3401        interactivity=interactivity, compiler=compiler, result=result)
#    3403 self.last_execution_succeeded = not has_raised
#
# File ~/.conda/envs/desc-env/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3641, in run_ast_nodes()
#    3640     asy = compare(code)
# -> 3641 if await self.run_code(code, result, async_=asy):
#    3642     return True
#
# File ~/.conda/envs/desc-env/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3701, in run_code()
#    3700     else:
# -> 3701         exec(code_obj, self.user_global_ns, self.user_ns)
#    3702 finally:
#    3703     # Reset our crash handler in place
#
# Cell In[13], line 3
#       2 start = time.time()
# ----> 3 runner.run()
#       5 end = time.time()
#
# File /global/u2/e/eatocco/projects/MaNTA/python/Stellarator.py:137, in dSigma()
#     136 # def dSigma_gpu(self, )
# --> 137 @partial(jax.jit, static_argnums=(0,1))
#     138 def dSources(self, index, states, positions, t):
#     139     x_s = jnp.array(positions)#jax.device_put(jnp.array(positions),sharding)
#
# File /global/u2/e/eatocco/projects/MaNTA/python/Stellarator.py:136, in <lambda>()
#     134     return out
# --> 136 # def dSigma_gpu(self, )
#     137 @partial(jax.jit, static_argnums=(0,1))
#     138 def dSources(self, index, states, positions, t):
#
# File /global/u2/e/eatocco/projects/MaNTA/python/Stellarator.py:173, in sigma()
#     171     return params.SourceHeight * jnp.exp(-(x - params.SourceCenter)**2 / (2 * params.SourceWidth**2))
# --> 173 #@partial(jax.jit, static_argnums=(0,1))
#     174 def dSigmaFn_dq( self, index, state, x, t):
#
# File /global/u2/e/eatocco/projects/MaNTA/python/yancc_wrapper.py:132, in flux()
#     122 species = [
#     123 LocalMaxwellian(
#     124     # can just give mass and charge in units of proton mass and elementary charge
#    (...)    129     dndrho=dndrho * self.nNorm),
#     130 ]
# --> 132 _, _, fluxes, stats  = solve_dke(field, self.pitchgrid, self.speedgrid, species, Erho, verbose = 0)
#     133 #assert stats['res'] < 1e-5
#
# File /global/u2/e/eatocco/projects/yancc/yancc/solve.py:345, in solve_dke()
#     343     f1 = jnp.pad(f1, [(0, 2 * len(species))])
# --> 345 f1, j1, nmv1, res1, C1, U1 = gcrotmk(
#     346     operator,
#     347     rhs,
#     348     x0=f1,
#     349     MR=preconditioner,
#     350     m=m,
#     351     k=k,
#     352     rtol=rtol,
#     353     atol=atol,
#     354     maxiter=maxiter,
#     355     print_every=print_every if verbose > 1 else 0,
#     356     U=U,
#     357 )
#     358 info = {
#     359     "niter": j1,
#     360     "nmv": nmv1,
#    (...)    363     "U": U1[:size],
#     364 }
#
# JaxStackTraceBeforeTransformation: jaxlib._jax.XlaRuntimeError: RESOURCE_EXHAUSTED: Out of memory while trying to allocate 15470569664 bytes.
#
# The preceding stack trace is the source of the JAX operation that, once transformed by JAX, triggered the following exception.
#
# --------------------
#
# The above exception was the direct cause of the following exception:
#
# XlaRuntimeError                           Traceback (most recent call last)
# Cell In[13], line 3
#       1 import time
#       2 start = time.time()
# ----> 3 runner.run()
#       5 end = time.time()
#       7 print("Elapsed time:")
#
# File /global/u2/e/eatocco/projects/MaNTA/python/Stellarator.py:137, in dSigma(self, index, states, positions, t)
#     134     return out
#     136 # def dSigma_gpu(self, )
# --> 137 @partial(jax.jit, static_argnums=(0,1))
#     138 def dSources(self, index, states, positions, t):
#     139     x_s = jnp.array(positions)#jax.device_put(jnp.array(positions),sharding)
#     140     g_vmap = jax.vmap(lambda s, p: jax.grad(self.source, argnums=1)(index, s, p, t, self.params), in_axes=(vmap_axes))
#
#     [... skipping hidden 7 frame]
#
# File /global/u2/e/eatocco/projects/MaNTA/python/Stellarator.py:136, in <lambda>(s, p, field, rho, vprime)
#     133     out["Scalars"] = []
#     134     return out
# --> 136 # def dSigma_gpu(self, )
#     137 @partial(jax.jit, static_argnums=(0,1))
#     138 def dSources(self, index, states, positions, t):
#     139     x_s = jnp.array(positions)#jax.device_put(jnp.array(positions),sharding)
#
#     [... skipping hidden 24 frame]
#
# File ~/.conda/envs/desc-env/lib/python3.12/site-packages/jax/_src/interpreters/pxla.py:1372, in ExecuteReplicated.__call__(self, *args)
#    1369 if (self.ordered_effects or self.has_unordered_effects
#    1370     or self.has_host_callbacks):
#    1371   input_bufs = self._add_tokens_to_inputs(input_bufs)
# -> 1372   results = self.xla_executable.execute_sharded(input_bufs, with_tokens=True)
#    1374   result_token_bufs = results.disassemble_prefix_into_single_device_arrays(
#    1375       len(self.ordered_effects))
#    1376   sharded_runtime_token = results.consume_token()
#
# XlaRuntimeError: RESOURCE_EXHAUSTED: Out of memory while trying to allocate 15470569664 bytes.
