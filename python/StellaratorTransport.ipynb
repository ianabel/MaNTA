# %%
# %reload_ext autoreload
# %autoreload 2 

import MaNTA

from Stellarator import StellaratorTransport

# %%
st_config = {
    "SourceCenter": 0.0,
    "SourceHeight": 50.0,
    "SourceWidth": 0.2,
    "EdgeTemperature":0.5,
    "EdgeDensity": 0.1,
    "n0": 0.5,
}

st = StellaratorTransport(st_config)
runner = MaNTA.Runner(st)
# Out:
# Initializing yancc wrapper with parameters:
#   nx=5, na=65, nt=17, nz=33
# yancc wrapper initialized successfully.

# %%
config = {
    "OutputFilename": "stellarator",
    "Polynomial_degree": 3,
    "Grid_size": 6,
    "tau": 1.0, 
    "Lower_boundary": 0.0,
    "Upper_boundary": 0.9,
    "Relative_tolerance": 0.01,
    "delta_t": 0.05,
    "restart": False,
    "solveAdjoint": True, 
}

runner.configure(config)
# Out:
# INFO: Using default value for configuration option High_Grid_Boundary
# INFO: Using default value for configuration option Lower_Boundary_Fraction
# INFO: Using default value for configuration option Upper_Boundary_Fraction
# INFO: Creating grid with 6 cells from x = 0 to x = 0.9
# 5721
# Total HDG degrees of freedom 79
# INFO: Using default value for configuration option Absolute_tolerance
# INFO: Using default value for configuration option tZero
# INFO: Using default value for configuration option MinStepSize
# INFO: Using default value for configuration option OutputPoints
# INFO: Using default value for configuration option SteadyStateTolerance
# INFO: Using default value for configuration option WriteOutput
# Setting initial conditions
# computing field
# Evaluating residual at time t=0
# Updating Jacobian at t=0
# Evaluating residual at time t=0
# Updating Jacobian at t=0
# Number of Residual Evaluations due to IDACalcIC 2
# Configuration done.

# %%
tFinal = 1.0
import time
import datetime

start = time.time()
finalState = runner.run_ss()

end = time.time()
time_duration = datetime.timedelta(seconds=end-start)
print("Elapsed time:")
print(time_duration)
# Out:
# Evaluating residual at time t=5e-05
# Updating Jacobian at t=5e-05
# Evaluating residual at time t=5e-05
# Evaluating residual at time t=0.0001
# Evaluating residual at time t=0.0002
# Evaluating residual at time t=0.0002
# Evaluating residual at time t=0.0004
# Updating Jacobian at t=0.0004
# Evaluating residual at time t=0.0004
# Evaluating residual at time t=0.0006
# Evaluating residual at time t=0.001
# Updating Jacobian at t=0.001
# Evaluating residual at time t=0.001
# Evaluating residual at time t=0.0018
# Updating Jacobian at t=0.0018
# Evaluating residual at time t=0.0018
# Evaluating residual at time t=0.0026
# Evaluating residual at time t=0.0034
# Evaluating residual at time t=0.005
# Evaluating residual at time t=0.005
# Evaluating residual at time t=0.0066
# Evaluating residual at time t=0.0082
# Evaluating residual at time t=0.0082
# Evaluating residual at time t=0.0098
# Evaluating residual at time t=0.0114
# Evaluating residual at time t=0.0114
# Evaluating residual at time t=0.0114
# Updating Jacobian at t=0.0114
# Evaluating residual at time t=0.0114
# Evaluating residual at time t=0.0127436
# Evaluating residual at time t=0.0127436
# Evaluating residual at time t=0.0139528
# Evaluating residual at time t=0.0139528
# Evaluating residual at time t=0.015162
# Evaluating residual at time t=0.0163712
# Evaluating residual at time t=0.0187897
# Evaluating residual at time t=0.0187897
# Evaluating residual at time t=0.0187897
# Evaluating residual at time t=0.0212081
# Evaluating residual at time t=0.0236266
# Evaluating residual at time t=0.0236266
# Evaluating residual at time t=0.0236266
# Evaluating residual at time t=0.0236266
# Evaluating residual at time t=0.0236266
# Updating Jacobian at t=0.0236266
# Evaluating residual at time t=0.0236266
# Evaluating residual at time t=0.026045
# Evaluating residual at time t=0.0284635
# Evaluating residual at time t=0.0308819
# Evaluating residual at time t=0.0308819
# Evaluating residual at time t=0.0308819
# Updating Jacobian at t=0.0308819
# Evaluating residual at time t=0.0308819
# Evaluating residual at time t=0.0333004
# Evaluating residual at time t=0.0357188
# Evaluating residual at time t=0.0405557
# Evaluating residual at time t=0.0405557
# Evaluating residual at time t=0.0405557
# Evaluating residual at time t=0.0453926
# Evaluating residual at time t=0.0550663
# Updating Jacobian at t=0.0550663
# Evaluating residual at time t=0.0550663
# Writing output at 0.05 ( 29 timesteps )
# Evaluating residual at time t=0.0647401
# Evaluating residual at time t=0.0744139
# Evaluating residual at time t=0.0840877
# Evaluating residual at time t=0.0937614
# Evaluating residual at time t=0.0937614
# Evaluating residual at time t=0.103435
# Writing output at 0.1 ( 34 timesteps )
# Steady State achieved at time t = 0.1
# Total Number of Timesteps             :34
# Total Number of Residual Evaluations  :62
# Total Number of Jacobian Computations :10
# Done.
#
# 0:07:02.888527

# %%
import matplotlib.pyplot as plt

plt.plot(finalState["Variable"])

# %%
G, G_p = runner.runAdjointSolve()
print("Stored energy: " + str(G))
print(G_p)
# Out:
# Computing adjoints
# (5720, 24)
