# %%
# %reload_ext autoreload
# %autoreload 2 

import MaNTA

from Stellarator import StellaratorTransport

# %%
st_config = {
    "SourceCenter": 0.0,
    "SourceHeight": 100.0,
    "SourceWidth": 0.15,
    "EdgeTemperature":0.5,
    "EdgeDensity": 0.1,
    "n0": 0.5,
}

st = StellaratorTransport(st_config)
runner = MaNTA.Runner(st)
# Out:
# Initializing yancc wrapper with parameters:
#   nx=5, na=65, nt=17, nz=33
# yancc wrapper initialized successfully.

# %%
config = {
    "OutputFilename": "stellarator",
    "Polynomial_degree": 3,
    "Grid_size": 6,
    "tau": 1.0, 
    "Lower_boundary": 0.0,
    "Upper_boundary": 0.9,
    "Relative_tolerance": 0.01,
    "delta_t": 0.1,
    "restart": False,
}

runner.configure(config)
# Out:
# INFO: Using default value for configuration option High_Grid_Boundary
# INFO: Using default value for configuration option Lower_Boundary_Fraction
# INFO: Using default value for configuration option Upper_Boundary_Fraction
# INFO: Creating grid with 6 cells from x = 0 to x = 0.9
# INFO: Using default value for configuration option solveAdjoint
# Total HDG degrees of freedom 79
# INFO: Using default value for configuration option Absolute_tolerance
# INFO: Using default value for configuration option tZero
# INFO: Using default value for configuration option MinStepSize
# INFO: Using default value for configuration option OutputPoints
# INFO: Using default value for configuration option WriteOutput
# Setting initial conditions
# computing field
# Evaluating residual at time t=0
# Updating Jacobian at t=0
# Evaluating residual at time t=0
# Updating Jacobian at t=0
# Number of Residual Evaluations due to IDACalcIC 2

# %%
tFinal = 1.0
import time
import datetime

start = time.time()
finalState = runner.run(tFinal)

end = time.time()
time_duration = datetime.timedelta(seconds=end-start)
print("Elapsed time:")
print(time_duration)
# Out:
# Evaluating residual at time t=0.0001
# Updating Jacobian at t=0.0001
# Evaluating residual at time t=0.0001
# Evaluating residual at time t=0.0002
# Evaluating residual at time t=0.0004
# Evaluating residual at time t=0.0004
# Evaluating residual at time t=0.0008
# Updating Jacobian at t=0.0008
# Evaluating residual at time t=0.0008
# Evaluating residual at time t=0.0012
# Evaluating residual at time t=0.0016
# Evaluating residual at time t=0.0024
# Evaluating residual at time t=0.0024
# Evaluating residual at time t=0.0032
# Evaluating residual at time t=0.004
# Evaluating residual at time t=0.004
# Evaluating residual at time t=0.0048
# Evaluating residual at time t=0.0056
# Evaluating residual at time t=0.0056
# Evaluating residual at time t=0.0056
# Updating Jacobian at t=0.0056
# Evaluating residual at time t=0.0056
# Evaluating residual at time t=0.00630952
# Evaluating residual at time t=0.00630952
# Evaluating residual at time t=0.00701903
# Evaluating residual at time t=0.00772855
# Evaluating residual at time t=0.00843806
# Evaluating residual at time t=0.00914758
# Evaluating residual at time t=0.00985709
# Evaluating residual at time t=0.00985709
# Evaluating residual at time t=0.00985709
# Evaluating residual at time t=0.00985709
# Evaluating residual at time t=0.00985709
# Evaluating residual at time t=0.00985709
# Evaluating residual at time t=0.00985709
# Updating Jacobian at t=0.00985709
# Evaluating residual at time t=0.00985709
# Evaluating residual at time t=0.0105666
# Evaluating residual at time t=0.0112761
# Evaluating residual at time t=0.0119856
# Evaluating residual at time t=0.0119856
# Evaluating residual at time t=0.0134047
# Evaluating residual at time t=0.0134047
# Evaluating residual at time t=0.0148237
# Evaluating residual at time t=0.0162427
# Evaluating residual at time t=0.0176618
# Evaluating residual at time t=0.0190808
# Evaluating residual at time t=0.0190808
# Evaluating residual at time t=0.0190808
# Updating Jacobian at t=0.0190808
# Evaluating residual at time t=0.0190808
# Evaluating residual at time t=0.0204998
# Evaluating residual at time t=0.0219189
# Evaluating residual at time t=0.0233379
# Evaluating residual at time t=0.0233379
# Evaluating residual at time t=0.0233379
# Updating Jacobian at t=0.0233379
# Evaluating residual at time t=0.0233379
# Evaluating residual at time t=0.0247569
# Evaluating residual at time t=0.027595
# Updating Jacobian at t=0.027595
# Evaluating residual at time t=0.027595
# Evaluating residual at time t=0.0300783
# Evaluating residual at time t=0.0300783
# Evaluating residual at time t=0.0325617
# Evaluating residual at time t=0.0350451
# Evaluating residual at time t=0.0400118
# Evaluating residual at time t=0.0400118
# Evaluating residual at time t=0.0449785
# Evaluating residual at time t=0.0549119
# Updating Jacobian at t=0.0549119
# Evaluating residual at time t=0.0549119
# Evaluating residual at time t=0.063852
# Evaluating residual at time t=0.063852
# Evaluating residual at time t=0.0727921
# Evaluating residual at time t=0.0817322
# Evaluating residual at time t=0.0906723
# Evaluating residual at time t=0.108553
# Updating Jacobian at t=0.108553
# Evaluating residual at time t=0.108553
# Writing output at 0.1 ( 41 timesteps )
# Evaluating residual at time t=0.144313
# Updating Jacobian at t=0.144313
# Evaluating residual at time t=0.144313
# Evaluating residual at time t=0.215834
# Updating Jacobian at t=0.215834
# Evaluating residual at time t=0.215834
# Writing output at 0.2 ( 43 timesteps )
# Evaluating residual at time t=0.358875
# Updating Jacobian at t=0.358875
# Writing output at 0.3 ( 44 timesteps )
# Evaluating residual at time t=0.644958
# Updating Jacobian at t=0.644958
# Writing output at 0.4 ( 45 timesteps )
# Writing output at 0.5 ( 45 timesteps )
# Writing output at 0.6 ( 45 timesteps )
# Evaluating residual at time t=1.21712
# Updating Jacobian at t=1.21712
# Writing output at 0.7 ( 46 timesteps )
# Elapsed time:
# Writing output at 0.8 ( 46 timesteps )
# Writing output at 0.9 ( 46 timesteps )
# Writing output at 1 ( 46 timesteps )
# Total Number of Timesteps             :46
# Total Number of Residual Evaluations  :80
# Total Number of Jacobian Computations :16
# Done.
# 0:10:54.467816

# %%
import matplotlib.pyplot as plt

plt.plot(finalState["Variable"])
