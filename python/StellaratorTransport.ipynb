# %%
# %reload_ext autoreload
# %autoreload 2

import MaNTA

from Stellarator import StellaratorTransport

# %%
st_config = {
    "SourceCenter": 0.05,
    "SourceHeight": 25.0,
    "SourceWidth": 0.2,
    "EdgeTemperature":0.5,
    "EdgeDensity": 0.1,
    "n0": 0.5,
}

st = StellaratorTransport(st_config)
runner = MaNTA.Runner(st)
# Out:
# Initializing yancc wrapper with parameters:
#   nx=5, na=65, nt=17, nz=33
# yancc wrapper initialized successfully.

# %%
config = {
    "OutputFilename": "stellarator3",
    "Polynomial_degree": 4,
    "Grid_size": 3,
    "tau": 2.0, 
    "Lower_boundary": 0.0,
    "Upper_boundary": 0.9,
    "Relative_tolerance": 0.01,
    "tFinal": 2.0,
    "delta_t": 0.5,
    "restart": True,
}

runner.configure(config)
# Out:
# INFO: Using default value for configuration option RestartFile
# INFO: Using default value for configuration option solveAdjoint
# Total HDG degrees of freedom 49
# INFO: Using default value for configuration option Absolute_tolerance
# INFO: Using default value for configuration option tZero
# INFO: Using default value for configuration option MinStepSize
# INFO: Using default value for configuration option OutputPoints

# %%
runner.run()
# Out:
# Setting initial conditions
# Evaluating residual
#   current residual norm: -nan
# Evaluating residual
#   current residual norm: 0
# Updating Jacobian at time 0
# Evaluating residual
#   current residual norm: 0.000839815
# Updating Jacobian at time 0
# Number of Residual Evaluations due to IDACalcIC 2
# Evaluating residual
#   current residual norm: 0.000102411
# Evaluating residual
#   current residual norm: inf
# Updating Jacobian at time 0.0005
# Evaluating residual
#   current residual norm: 1.29631
# Evaluating residual
#   current residual norm: 0.114767
# Evaluating residual
#   current residual norm: 0.161653
# Evaluating residual
#   current residual norm: 0.524096
# Evaluating residual
#   current residual norm: 0.0418473
# Updating Jacobian at time 0.004
# Evaluating residual
#   current residual norm: 1.10233
# Evaluating residual
#   current residual norm: 0.105647
# Evaluating residual
#   current residual norm: 0.467376
# Evaluating residual
#   current residual norm: 0.0870272
# Evaluating residual
#   current residual norm: 0.41233
# Evaluating residual
#   current residual norm: 0.341526
# Evaluating residual
#   current residual norm: 0.255557
# Updating Jacobian at time 0.0146218
# Evaluating residual
#   current residual norm: 0.856744
# Evaluating residual
#   current residual norm: 0.0835387
# Evaluating residual
#   current residual norm: 0.557341
# Evaluating residual
#   current residual norm: 0.459942
# Evaluating residual
#   current residual norm: 0.358428
# Updating Jacobian at time 0.0323248
# Evaluating residual
#   current residual norm: 1.52427
# Evaluating residual
#   current residual norm: 0.142388
# Evaluating residual
#   current residual norm: 0.989629
# Evaluating residual
#   current residual norm: 0.120737
# Evaluating residual
#   current residual norm: 0.891183
# Evaluating residual
#   current residual norm: 0.682634
# Evaluating residual
#   current residual norm: 0.984578
# Evaluating residual
#   current residual norm: 0.112101
# Evaluating residual
#   current residual norm: 0.409176
# Evaluating residual
#   current residual norm: 0.475562
# Evaluating residual
#   current residual norm: 0.921468
# Updating Jacobian at time 0.115175
# Evaluating residual
#   current residual norm: 0.510629
# Evaluating residual
#   current residual norm: 0.0244053
# Evaluating residual
#   current residual norm: 0.116475
# Updating Jacobian at time 0.153413
# Evaluating residual
#   current residual norm: 0.169293
# Evaluating residual
#   current residual norm: 0.0308201
# Updating Jacobian at time 0.204398
# Evaluating residual
#   current residual norm: 0.259743
# Evaluating residual
#   current residual norm: 0.00535811
# Updating Jacobian at time 0.306367
# Evaluating residual
#   current residual norm: 0.170281
# Evaluating residual
#   current residual norm: 0.0105378
# Updating Jacobian at time 0.510306
# Evaluating residual
#   current residual norm: 0.0590082
# Writing output at 0.5 ( 26 timesteps )
# Evaluating residual
#   current residual norm: 0.000102411
# Evaluating residual
#   current residual norm: 0.00169039
# Updating Jacobian at time 0.918184
# Evaluating residual
#   current residual norm: 0.00914117
# Updating Jacobian at time 1.73394
# Writing output at 1 ( 28 timesteps )
# Evaluating residual
#   current residual norm: 0.000412298
# Writing output at 1.5 ( 28 timesteps )
# Evaluating residual
#   current residual norm: 3.85555e-05
# Evaluating residual
#   current residual norm: 0.0043642
# Updating Jacobian at time 3.36545
# Writing output at 2 ( 29 timesteps )
# Evaluating residual
#   current residual norm: 0.000199206
# Total Number of Timesteps             :29
# Total Number of Residual Evaluations  :44
# Total Number of Jacobian Computations :14
# 0
# Done.
