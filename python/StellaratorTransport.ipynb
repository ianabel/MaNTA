# %%
# %reload_ext autoreload
# %autoreload 2 
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"
os.environ["HDF5_USE_FILE_LOCKING"]= "FALSE"
    
import MaNTA
from Objective2 import (make_objective, make_objective_fd)
from Stellarator2 import StellaratorTransport

from yancc_wrapper2 import yancc_data
# Out:
# Registering cpu implementation for operation get_solution
# Registering gpu implementation for operation get_solution
# Registering cpu implementation for operation get_adjoint_gradients
# Registering gpu implementation for operation get_adjoint_gradients
# Registering cpu implementation for operation run
# Registering cpu implementation for operation run_ss
# Using cache directory: /global/cfs/cdirs/mp217/eatocco/__pycache__
# [CudaDevice(id=0), CudaDevice(id=1), CudaDevice(id=2), CudaDevice(id=3)]

# %%
# # %%
# st_config = {
#     "SourceCenter": 0.0,
#     "SourceHeight": 30.0,
#     "SourceWidth": 0.2,
#     "EdgeTemperature":0.5,
#     "EdgeDensity": 0.1,
#     "n0": 0.5,
# }
# # runner = MaNTA.Runner(st)

# # # %%
# solver_config = {
#     "OutputFilename": "stellarator2",
#     "Polynomial_degree": 3,
#     "Grid_size": 6,
#     "tau": 1.0, 
#     "Lower_boundary": 0.0,
#     "Upper_boundary": 1.0,
#     "Relative_tolerance": 0.01,
#     "delta_t": 0.01,
#     "restart": False,
#     "solveAdjoint": True, 
# }

# config = {
#     "Stellarator": st_config,
#     "Solver": solver_config,
# }

# points =  MaNTA.getNodes(solver_config["Lower_boundary"], solver_config["Upper_boundary"], solver_config["Grid_size"], solver_config["Polynomial_degree"])
# Density = lambda x : (st_config["n0"] - st_config["EdgeDensity"]) * (1 - x*x) + st_config["EdgeDensity"]

# yancc_wrapper = yancc_data.from_eq(points, Density=Density)

# st = StellaratorTransport(config, yancc_wrapper=yancc_wrapper)
# # field_ = st.field
# # grid_ = yancc_wrapper.grid
# vprim_ = st.vprime

# %%
import desc
from desc import set_device
set_device("gpu")

from desc.equilibrium import Equilibrium
from desc.geometry import FourierRZToroidalSurface
from desc.grid import Grid, LinearGrid
from desc.objectives import (
    AspectRatio,
    FixBoundaryR,
    FixBoundaryZ,
    FixCurrent,
    FixPsi,
    ForceBalance,
    LinearObjectiveFromUser,
    ObjectiveFunction,
    ObjectiveFromUser,
    RotationalTransform,
    Volume,
)
from desc.profiles import SplineProfile
from desc.plotting import (
    plot_grid,
    plot_boozer_modes,
    plot_boozer_surface,
    plot_qs_error,
    plot_boundaries,
    plot_boundary,
)
import equinox as eqx
import jax 
import jax.numpy as jnp

st_config = {
    "SourceCenter": 0.2,
    "SourceHeight": 350.0,
    "SourceWidth": 0.4,
    "EdgeTemperature":0.2,
    "EdgeDensity": 0.0,
    "n0": 0.25,
}
# runner = MaNTA.Runner(st)

solver_config = {
    "OutputFilename": "stellarator_opt",
    "Polynomial_degree": 4,
    "Grid_size": 4,
    "tau": 100.0, 
    "Lower_boundary": 0.0,
    "Upper_boundary": 1.0,
    "Relative_tolerance": 0.01,
    "Absolute_tolerance": [1e-3],
    "delta_t": 1e-4,
    "MinStepSize": 1e-8, 
    "SteadyStateTolerance": 1e-2,
    "restart": False,
    "solveAdjoint": True, 
    "zeroFlux": True,
}
config = {
    "Stellarator": st_config,
    "Solver": solver_config,
}

points =  MaNTA.getNodes(solver_config["Lower_boundary"], solver_config["Upper_boundary"], solver_config["Grid_size"], solver_config["Polynomial_degree"])

yancc_rho = jnp.array(points)
yancc_ntheta = 17
yancc_nzeta = 33

       
# to allow maximum flexibility to match manta, we use a spline with the same control points as manta \
# + axis and lcfs
# initial pressure is all zeros, can change this if desired
pressure_rho = jnp.concatenate([jnp.zeros(1), yancc_rho, jnp.ones(1)])
desc_pressure = SplineProfile(jnp.zeros_like(pressure_rho), pressure_rho)

eq = desc.examples.get("W7-X")
eq.change_resolution(M=4, N=4,L_grid=len(points), M_grid=4, N_grid=4)
eq = eq.solve(x_scale="ess")[0]
# # eq = eq.solve(x_scale="ess")[0]
# # # store initial equilibrium for comparison later
# eq_init = eq.copy()
# yancc_grid = desc.grid.LinearGrid(rho=yancc_rho, M=eq_init.M_grid, N = eq_init.N_grid, NFP=eq_init.NFP)
# points =  MaNTA.getNodes(solver_config["Lower_boundary"], solver_config["Upper_boundary"], solver_config["Grid_size"], solver_config["Polynomial_degree"])
# yancc_wrapper = yancc_data.from_eq(points, grid = yancc_grid,rho = yancc_rho, Density=Density, eq=eq_init, nt = yancc_ntheta, nz = yancc_nzeta)
nx = 5
na = 43

yancc_wrapper = yancc_data.from_eq(points, eq=eq, nx=nx, na=na)

V0 = eq.compute("V")["V"]
# Out:
# /global/cfs/cdirs/mp217/eatocco/DESC/desc/__init__.py:151: UserWarning: CUDA_VISIBLE_DEVICES= did not match any physical GPU (id=['0', '1', '2', '3']), falling back to CPU
#   warnings.warn(
# Building objective: force
# Precomputing transforms
# Building objective: lcfs R
# Building objective: lcfs Z
# Building objective: fixed Psi
# Building objective: fixed pressure
# Building objective: fixed iota
# Building objective: fixed sheet current
# Building objective: self_consistency R
# Building objective: self_consistency Z
# Building objective: lambda gauge
# Building objective: axis R self consistency
# Building objective: axis Z self consistency
# Number of parameters: 604
# Number of objectives: 594
#
# Starting optimization
# Using method: lsq-exact
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 1.869e-10
#          Total delta_x: 1.202e-01
#          Iterations: 100
#          Function evaluations: 112
#          Jacobian evaluations: 101
# ==============================================================================================================
#                                                                  Start  -->   End
# Total (sum of squares):                                      1.055e-01  -->   1.869e-10,
# Maximum absolute Force error:                                4.015e+07  -->   4.740e+02 (N)
# Minimum absolute Force error:                                9.015e+01  -->   3.423e-01 (N)
# Average absolute Force error:                                9.204e+05  -->   3.932e+01 (N)
# Maximum absolute Force error:                                2.171e-01  -->   2.564e-06 (normalized)
# Minimum absolute Force error:                                4.875e-07  -->   1.851e-09 (normalized)
# Average absolute Force error:                                4.977e-03  -->   2.126e-07 (normalized)
# R boundary error:                                            0.000e+00  -->   2.914e-17 (m)
# Z boundary error:                                            0.000e+00  -->   2.799e-17 (m)
# Fixed Psi error:                                             0.000e+00  -->   0.000e+00 (Wb)
# Fixed pressure profile error:                                0.000e+00  -->   0.000e+00 (Pa)
# Fixed iota profile error:                                    0.000e+00  -->   0.000e+00 (dimensionless)
# Fixed sheet current error:                                   0.000e+00  -->   0.000e+00 (~)
# ==============================================================================================================
#
# Initializing yancc wrapper
# yancc_wrapper initialized successfully.

# %%
# st = StellaratorTransport(config, yancc_wrapper=yancc_wrapper)

# st.run()

# %%
# import time
# import datetime

# tFinal = 1.0

# start = time.time()

# st.run()

# end = time.time()
# time_duration = datetime.timedelta(seconds=end-start)
# print("Elapsed time:")
# print(time_duration)

# %%
# import matplotlib.pyplot as plt
# u = st.getPressure()

# plt.plot(points, u)

# %%
# @eqx.filter_custom_jvp
# def Objective(fields, grid, yin):
#     yancc_wrapper = yancc_data.from_other(fields, grid, yin)

#     solver_config = {
#         "OutputFilename": "stellarator_opt",
#         "Polynomial_degree": 3,
#         "Grid_size": 6,
#         "tau": 100.0, 
#         "Lower_boundary": 0.0,
#         "Upper_boundary": 0.9,
#         "Relative_tolerance": 0.01,
#         "delta_t": 0.001,
#         "restart": True,
#         "solveAdjoint": True, 
#     }

#     config = {
#         "Stellarator": st_config,
#         "Solver": solver_config,
#     }
#     st = StellaratorTransport(config, yancc_wrapper=yancc_wrapper)
#     st.run()
#     G, G_p = st.runAdjointSolve()

#     pi = jnp.array(st.getPressure())

#     return G[0], pi

# @Objective.def_jvp
# def Objective_jvp(primals, tangents):
#     fields, grid, yin = primals
#     field_dot,_,_ = tangents
#     yancc_wrapper = yancc_data.from_other(fields, grid, yin)

#     solver_config = {
#         "OutputFilename": "stellarator_opt",
#         "Polynomial_degree": 3,
#         "Grid_size": 6,
#         "tau": 100.0, 
#         "Lower_boundary": 0.0,
#         "Upper_boundary": 0.9,
#         "Relative_tolerance": 0.01,
#         "delta_t": 0.001,
#         "restart": True,
#         "solveAdjoint": True, 
#     }

#     config = {
#         "Stellarator": st_config,
#         "Solver": solver_config,
#     }
#     st = StellaratorTransport(config, yancc_wrapper=yancc_wrapper)
#     st.run()
#     G, G_p = st.runAdjointSolve()
#     pi = jnp.array(st.getPressure())
    
#     field_dot_flatten,_ = jax.flatten_util.ravel_pytree(field_dot)

#     return (G[0], pi), (jnp.float32(jnp.dot(G_p.flatten(), field_dot_flatten)), None)

# %%
solver_config = {
    "OutputFilename": "stellarator_opt",
    "Polynomial_degree": 4,
    "Grid_size": 4,
    "tau": 100.0, 
    "Lower_boundary": 0.0,
    "Upper_boundary": 1.0,
    "Relative_tolerance": 0.01,
    "Absolute_tolerance": [1e-3],
    "delta_t": 1e-4,
    "MinStepSize": 1e-8, 
    "SteadyStateTolerance": 1e-2,
    "restart": False,
    "solveAdjoint": True, 
    "zeroFlux": True,
}

config = {
    "Stellarator": st_config,
    "Solver": solver_config,
}


# Objective_fd = make_objective_fd(config)
# g = eqx.filter_grad(Objective, has_aux=True)
# g_fd = eqx.filter_grad(Objective_fd, has_aux=True)
# fields = yancc_wrapper.fields
# grid = yancc_wrapper.grid

# Vprime = yancc_wrapper.Vprim

# # g_fd_out = g_fd((fields,Vprime), grid)
# g_out = g((fields, Vprime), grid)

# # print(g(fields, grid, Vprime))

# %%
# import matplotlib.pyplot as plt

# fig, ax = plt.subplots()

# (field_grad, dvp), pressure = g_out
# ax.plot(dvp, label="adjoints")
# # ax.plot(g_fd_out.Bmag_fsa, label="finite_differences")

# ax.legend()

# fig, ax = plt.subplots()

# ax.plot(jnp.sum(field_grad.sqrtg, axis=2))
# ax.plot(g_fd_out.sqrtg, label="finite_differences")

# %%
import yancc
yancc_desc_grid = yancc_wrapper.grid 
manta_objective = make_objective_fd(config)

def objective_from_user_fun(grid, data):
  # note: don't change the signature to this function
    yancc_dat = {
        "B_sup_t": data["B^theta"],
        "B_sup_z": data["B^zeta"],
        "B_sub_t": data["B_theta"],
        "B_sub_z": data["B_zeta"],
        "Bmag": data["|B|"],
        "dBdt": data["|B|_t"],
        "dBdz": data["|B|_z"],
        "sqrtg": data["sqrt(g)"],
    }

    yancc_dat = {
        key: grid.meshgrid_reshape(val, "rtz") for key, val in yancc_dat.items()
    }

    yancc_dat["Psi"] = grid.compress(
        data["Psi"] / grid.nodes[:, 0] ** 2, surface_label="rho"
    )
    yancc_dat["a_minor"] = jnp.full(grid.num_rho, data["a"])
    yancc_dat["R_major"] = jnp.full(grid.num_rho, data["R0"])
    yancc_dat["iota"] = grid.compress(data["iota"], surface_label="rho")
    yancc_dat["rho"] = grid.compress(grid.nodes[:, 0], surface_label="rho")

    V = grid.compress(data['V(r)'])
    V_r = grid.compress(data['V_r(r)'])
    V_rr = grid.compress(data['V_rr(r)'])
    Vp = V_r/V[-1]
    Vpp = V_rr/V[-1]
    
    fields = jax.vmap(lambda d: yancc.field.Field(**d, NFP=grid.NFP))(yancc_dat)

    desc_pressure = grid.compress(data["p"], surface_label="rho")
    
    stored_energy, manta_pressure = manta_objective((fields, Vp, Vpp), grid)
    print("------------ STORED ENERGY ----------------")
    print(stored_energy)
    print("-------------------------------------------")
    
    pressure_error = desc_pressure - manta_pressure

    print("------------TOTAL PRESSURE ERROR-----------")
    print(pressure_error)
    print("-------------------------------------------")

    # optimization is easiest for least squares objectives, so instead of maximizing
    # stored energy we minimize 1/stored_energy^2 (the squaring happens later)
    return jnp.append(pressure_error, 1 / stored_energy)

pressure_error_weight = jnp.full(yancc_desc_grid.num_rho, 0.0)
stored_energy_weight = 100.0
objective_from_user_weight = jnp.append(pressure_error_weight, stored_energy_weight)

objfun = ObjectiveFromUser(
    objective_from_user_fun,
    eq,
    target=0,
    weight=objective_from_user_weight,
    grid=yancc_desc_grid,
    deriv_mode="fwd")
    # need this assuming manta only has vjp, if using jvp switch to fwd
 
# objfun = ObjectiveFunction(objectives)
objfun.build(use_jit=False)
J = 0
with jax.default_device(jax.devices('cpu')[0]):
    J = objfun.jac_scaled(eq.params_dict)
    print(J)
# Out:
# yancc_wrapper initialized successfully.
# configuring
# Successfully created StellaratorTransport object
# ------------ STORED ENERGY ----------------
# JitTracer(float32[])
# -------------------------------------------
# ------------TOTAL PRESSURE ERROR-----------
# JitTracer(float64[20])
# -------------------------------------------
# Total HDG degrees of freedom 65
# Configuration done.
# yancc_wrapper initialized successfully.
# configuring
# Successfully created StellaratorTransport object
# Total HDG degrees of freedom 65
# Configuration done.
# Setting initial conditions
# Residual norm at t = 0: inf
# Residual norm at t = 0: 0
# Residual norm at t = 0: 0
# Residual norm at t = 0: 0.00388399
# Number of Residual Evaluations due to IDACalcIC 3
# Residual norm at t = 0: 0.00350222
# Residual norm at t = 1e-07: 0
# Residual norm at t = 1e-07: 0.0353178
# Residual norm at t = 2e-07: 9.18658e-07
# Residual norm at t = 4e-07: 2.38064e-05
# Residual norm at t = 8e-07: 1.17143e-05
# Residual norm at t = 1.6e-06: 0.000133259
# Residual norm at t = 3.2e-06: 5.04703e-05
# Residual norm at t = 6.4e-06: 0.000171596
# Residual norm at t = 1.28e-05: 0.000381019
# Residual norm at t = 2.56e-05: 0.0021725
# Residual norm at t = 2.56e-05: 0.0310403
# Residual norm at t = 5.12e-05: 3.06358e-05
# Residual norm at t = 5.12e-05: 0.259101
# Residual norm at t = 7.68e-05: 0.00129679
# Residual norm at t = 0.0001024: 0.386594
# Writing output at 0.0001 ( 12 timesteps )
# Residual norm at t = 0.0001: 0.00546118
# Residual norm at t = 0.000128: 0.24975
#  dy/dt norm inferred from lambdas is 26.1048
# Residual norm at t = 0.0001536: 0.135836
# Residual norm at t = 0.0001536: 0.0940262
# Residual norm at t = 0.0002048: 0.00751478
# Residual norm at t = 0.0002048: 0.138809
# Writing output at 0.0002 ( 15 timesteps )
# Residual norm at t = 0.0002: 0.407553
# Residual norm at t = 0.000256: 0.0638767
#  dy/dt norm inferred from lambdas is 22.6514
# Residual norm at t = 0.000256: 0.556851
# Residual norm at t = 0.0003072: 0.170382
# Residual norm at t = 0.0003072: 0.726667
# Residual norm at t = 0.0003072: 0.772222
# Residual norm at t = 0.0003072: 0.385345
# Writing output at 0.0003 ( 17 timesteps )
# Residual norm at t = 0.0003: 0.192435
#  dy/dt norm inferred from lambdas is 19.9804
# Residual norm at t = 0.0003584: 4.86033e-05
# Residual norm at t = 0.0004096: 0.385378
# Writing output at 0.0004 ( 19 timesteps )
# Residual norm at t = 0.0004: 0.536826
#  dy/dt norm inferred from lambdas is 17.8327
# Residual norm at t = 0.0004608: 0.327707
# Residual norm at t = 0.0004608: 0.310799
# Residual norm at t = 0.000512: 0.143193
# Writing output at 0.0005 ( 21 timesteps )
# Residual norm at t = 0.0005: 0.521958
#  dy/dt norm inferred from lambdas is 16.1025
# Residual norm at t = 0.0006144: 0.122562
# Residual norm at t = 0.0006144: 0.346806
# Writing output at 0.0006 ( 22 timesteps )
# Residual norm at t = 0.0006: 0.201411
# Residual norm at t = 0.0007168: 0.000309251
#  dy/dt norm inferred from lambdas is 14.6774
# Writing output at 0.0007 ( 23 timesteps )
# Residual norm at t = 0.0007: 1.06291
# Residual norm at t = 0.0008192: 0.318751
#  dy/dt norm inferred from lambdas is 13.4787
# Writing output at 0.0008 ( 24 timesteps )
# Residual norm at t = 0.0008: 0.717415
#  dy/dt norm inferred from lambdas is 12.4728
# Residual norm at t = 0.0009216: 0.319591
# Writing output at 0.0009 ( 25 timesteps )
# Residual norm at t = 0.0009: 0.740126
#  dy/dt norm inferred from lambdas is 11.5908
# Residual norm at t = 0.001024: 0.288804
# Residual norm at t = 0.001024: 0.411646
# Writing output at 0.001 ( 26 timesteps )
# Residual norm at t = 0.001: 0.725876
#  dy/dt norm inferred from lambdas is 10.8331
# Residual norm at t = 0.0011264: 0.193932
# Writing output at 0.0011 ( 27 timesteps )
# Residual norm at t = 0.0011: 0.257449
#  dy/dt norm inferred from lambdas is 10.1697
# Residual norm at t = 0.0013312: 0.0595737
# Residual norm at t = 0.0013312: 1.82012
# Residual norm at t = 0.0013312: 3.16963
# Residual norm at t = 0.0013312: 0.702059
# Writing output at 0.0012 ( 28 timesteps )
# Residual norm at t = 0.0012: 0.284763
#  dy/dt norm inferred from lambdas is 9.55871
# Writing output at 0.0013 ( 28 timesteps )
# Residual norm at t = 0.0013: 0.824262
#  dy/dt norm inferred from lambdas is 9.00147
# Residual norm at t = 0.00151552: 0.000417936
# Residual norm at t = 0.00151552: 0.595254
# Writing output at 0.0014 ( 29 timesteps )
# Residual norm at t = 0.0014: 1.01577
#  dy/dt norm inferred from lambdas is 8.51184
# Writing output at 0.0015 ( 29 timesteps )
# Residual norm at t = 0.0015: 1.26914
#  dy/dt norm inferred from lambdas is 8.06063
# Residual norm at t = 0.00169984: 0.0573603
# Writing output at 0.0016 ( 30 timesteps )
# Residual norm at t = 0.0016: 0.285372
#  dy/dt norm inferred from lambdas is 7.6412
# Residual norm at t = 0.00188416: 0.212635
# Writing output at 0.0017 ( 31 timesteps )
# Residual norm at t = 0.0017: 0.997888
#  dy/dt norm inferred from lambdas is 7.25937
# Writing output at 0.0018 ( 31 timesteps )
# Residual norm at t = 0.0018: 0.580695
#  dy/dt norm inferred from lambdas is 6.90853
# Residual norm at t = 0.00206848: 0.206687
# Writing output at 0.0019 ( 32 timesteps )
# Residual norm at t = 0.0019: 0.407902
#  dy/dt norm inferred from lambdas is 6.57408
# Writing output at 0.002 ( 32 timesteps )
# Residual norm at t = 0.002: 0.58898
# Residual norm at t = 0.0022528: 0.302152
#  dy/dt norm inferred from lambdas is 6.25701
# Writing output at 0.0021 ( 33 timesteps )
# Residual norm at t = 0.0021: 0.569317
#  dy/dt norm inferred from lambdas is 6.00697
# Writing output at 0.0022 ( 33 timesteps )
# Residual norm at t = 0.0022: 0.781125
#  dy/dt norm inferred from lambdas is 5.79083
# Residual norm at t = 0.00243712: 1.18257
# Residual norm at t = 0.00243712: 4.73128
# Residual norm at t = 0.00243712: 6.3627
# Residual norm at t = 0.00243712: 2.23501
# Writing output at 0.0023 ( 34 timesteps )
# Residual norm at t = 0.0023: 0.844485
#  dy/dt norm inferred from lambdas is 5.45061
# Writing output at 0.0024 ( 34 timesteps )
# Residual norm at t = 0.0024: 1.81161
# Residual norm at t = 0.00259599: 0.0217386
#  dy/dt norm inferred from lambdas is 5.17494
# Residual norm at t = 0.00259599: 2.20532
# Writing output at 0.0025 ( 35 timesteps )
# Residual norm at t = 0.0025: 0.787938
#  dy/dt norm inferred from lambdas is 5.01287
# Residual norm at t = 0.00273897: 0.233178
# Residual norm at t = 0.00273897: 1.17274
# Writing output at 0.0026 ( 36 timesteps )
# Residual norm at t = 0.0026: 1.39225
#  dy/dt norm inferred from lambdas is 4.80962
# Writing output at 0.0027 ( 36 timesteps )
# Residual norm at t = 0.0027: 0.770445
#  dy/dt norm inferred from lambdas is 4.61582
# Residual norm at t = 0.00288195: 0.151057
# Writing output at 0.0028 ( 37 timesteps )
# Residual norm at t = 0.0028: 0.356259
#  dy/dt norm inferred from lambdas is 4.4291
# Residual norm at t = 0.00302493: 0.278315
# Writing output at 0.0029 ( 38 timesteps )
# Residual norm at t = 0.0029: 0.649728
#  dy/dt norm inferred from lambdas is 4.25283
# Writing output at 0.003 ( 38 timesteps )
# Residual norm at t = 0.003: 0.718475
# Residual norm at t = 0.0031679: 0.808819
#  dy/dt norm inferred from lambdas is 4.08645
# Writing output at 0.0031 ( 39 timesteps )
# Residual norm at t = 0.0031: 0.341532
# Residual norm at t = 0.00331088: 0.427088
#  dy/dt norm inferred from lambdas is 3.92637
# Residual norm at t = 0.00331088: 0.221374
# Writing output at 0.0032 ( 40 timesteps )
# Residual norm at t = 0.0032: 0.506244
#  dy/dt norm inferred from lambdas is 3.77476
# Writing output at 0.0033 ( 40 timesteps )
# Residual norm at t = 0.0033: 0.30834
# Residual norm at t = 0.00345386: 0.0184016
#  dy/dt norm inferred from lambdas is 3.63015
# Writing output at 0.0034 ( 41 timesteps )
# Residual norm at t = 0.0034: 0.0608595
# Residual norm at t = 0.00359684: 0.125433
#  dy/dt norm inferred from lambdas is 3.49126
# Writing output at 0.0035 ( 42 timesteps )
# Residual norm at t = 0.0035: 0.109193
#  dy/dt norm inferred from lambdas is 3.35862
# Residual norm at t = 0.00373982: 0.0749798
# Writing output at 0.0036 ( 43 timesteps )
# Residual norm at t = 0.0036: 0.0946529
#  dy/dt norm inferred from lambdas is 3.23147
# Writing output at 0.0037 ( 43 timesteps )
# Residual norm at t = 0.0037: 0.094411
# Residual norm at t = 0.00402578: 0.0708819
#  dy/dt norm inferred from lambdas is 3.10945
# Residual norm at t = 0.00402578: 1.29033
# Residual norm at t = 0.00402578: 1.90037
# Residual norm at t = 0.00402578: 0.537873
# Writing output at 0.0038 ( 44 timesteps )
# Residual norm at t = 0.0038: 0.0830848
#  dy/dt norm inferred from lambdas is 2.99259
# Writing output at 0.0039 ( 44 timesteps )
# Residual norm at t = 0.0039: 0.197982
#  dy/dt norm inferred from lambdas is 2.8803
# Writing output at 0.004 ( 44 timesteps )
# Residual norm at t = 0.004: 0.250997
# Residual norm at t = 0.00431174: 0.000748156
#  dy/dt norm inferred from lambdas is 2.7723
# Residual norm at t = 0.00431174: 0.41967
# Writing output at 0.0041 ( 45 timesteps )
# Residual norm at t = 0.0041: 0.218477
#  dy/dt norm inferred from lambdas is 2.66807
# Writing output at 0.0042 ( 45 timesteps )
# Residual norm at t = 0.0042: 0.234131
#  dy/dt norm inferred from lambdas is 2.56836
# Writing output at 0.0043 ( 45 timesteps )
# Residual norm at t = 0.0043: 0.183674
# Residual norm at t = 0.0045977: 0.0626435
#  dy/dt norm inferred from lambdas is 2.47246
# Writing output at 0.0044 ( 46 timesteps )
# Residual norm at t = 0.0044: 0.0295142
#  dy/dt norm inferred from lambdas is 2.38031
# Writing output at 0.0045 ( 46 timesteps )
# Residual norm at t = 0.0045: 0.231266
# Residual norm at t = 0.00488366: 0.199371
#  dy/dt norm inferred from lambdas is 2.29135
# Writing output at 0.0046 ( 47 timesteps )
# Residual norm at t = 0.0046: 0.116804
#  dy/dt norm inferred from lambdas is 2.20619
# Writing output at 0.0047 ( 47 timesteps )
# Residual norm at t = 0.0047: 0.169372
#  dy/dt norm inferred from lambdas is 2.12366
# Writing output at 0.0048 ( 47 timesteps )
# Residual norm at t = 0.0048: 0.132512
# Residual norm at t = 0.00545558: 0.0716381
#  dy/dt norm inferred from lambdas is 2.04382
# Residual norm at t = 0.00545558: 0.316668
# Writing output at 0.0049 ( 48 timesteps )
# Residual norm at t = 0.0049: 0.0477137
#  dy/dt norm inferred from lambdas is 1.96974
# Writing output at 0.005 ( 48 timesteps )
# Residual norm at t = 0.005: 0.522016
#  dy/dt norm inferred from lambdas is 1.8967
# Writing output at 0.0051 ( 48 timesteps )
# Residual norm at t = 0.0051: 0.664477
#  dy/dt norm inferred from lambdas is 1.82581
# Writing output at 0.0052 ( 48 timesteps )
# Residual norm at t = 0.0052: 0.721292
#  dy/dt norm inferred from lambdas is 1.75694
# Writing output at 0.0053 ( 48 timesteps )
# Residual norm at t = 0.0053: 0.694828
#  dy/dt norm inferred from lambdas is 1.68996
# Writing output at 0.0054 ( 48 timesteps )
# Residual norm at t = 0.0054: 0.587387
#  dy/dt norm inferred from lambdas is 1.62477
# Residual norm at t = 0.0060275: 7.07711e-05
# Writing output at 0.0055 ( 49 timesteps )
# Residual norm at t = 0.0055: 0.401248
#  dy/dt norm inferred from lambdas is 1.56934
# Writing output at 0.0056 ( 49 timesteps )
# Residual norm at t = 0.0056: 1.56493
#  dy/dt norm inferred from lambdas is 1.50969
# Writing output at 0.0057 ( 49 timesteps )
# Residual norm at t = 0.0057: 1.51184
#  dy/dt norm inferred from lambdas is 1.45146
# Writing output at 0.0058 ( 49 timesteps )
# Residual norm at t = 0.0058: 1.34212
#  dy/dt norm inferred from lambdas is 1.39459
# Writing output at 0.0059 ( 49 timesteps )
# Residual norm at t = 0.0059: 1.05837
#  dy/dt norm inferred from lambdas is 1.33899
# Writing output at 0.006 ( 49 timesteps )
# Residual norm at t = 0.006: 0.66292
#  dy/dt norm inferred from lambdas is 1.28459
# Residual norm at t = 0.00659942: 0.26188
# Writing output at 0.0061 ( 50 timesteps )
# Residual norm at t = 0.0061: 0.157974
#  dy/dt norm inferred from lambdas is 1.24526
# Writing output at 0.0062 ( 50 timesteps )
# Residual norm at t = 0.0062: 1.9578
#  dy/dt norm inferred from lambdas is 1.19673
# Writing output at 0.0063 ( 50 timesteps )
# Residual norm at t = 0.0063: 1.82345
#  dy/dt norm inferred from lambdas is 1.14914
# Writing output at 0.0064 ( 50 timesteps )
# Residual norm at t = 0.0064: 1.55794
#  dy/dt norm inferred from lambdas is 1.10245
# Writing output at 0.0065 ( 50 timesteps )
# Residual norm at t = 0.0065: 1.16351
# Residual norm at t = 0.00774325: 0.150021
#  dy/dt norm inferred from lambdas is 1.05659
# Residual norm at t = 0.00774325: 0.577911
# Writing output at 0.0066 ( 51 timesteps )
# Residual norm at t = 0.0066: 0.64223
#  dy/dt norm inferred from lambdas is 1.0329
# Writing output at 0.0067 ( 51 timesteps )
# Residual norm at t = 0.0067: 3.626
#  dy/dt norm inferred from lambdas is 0.995732
# Steady State achieved at time t = 0.0067
# Total Number of Timesteps             :51
# Total Number of Residual Evaluations  :82
# Total Number of Jacobian Computations :17
# Computing adjoints
# INFO: Computing adjoints for 858 parameters
# Successfully computed dgdp
# 858
# 20
# Done.

# %%
import matplotlib.pyplot as plt
print(J.keys())
plt.plot(J["L_lmn"][-1,:])
