# %%
# %reload_ext autoreload
# %autoreload 2 
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"
os.environ["HDF5_USE_FILE_LOCKING"]= "FALSE"
    
import MaNTA
from Objective import (make_objective, make_objective_fd)
from Stellarator import StellaratorTransport

from yancc_wrapper import yancc_data
# Out:
# Using gpu implementation for operation get_solution
# Using gpu implementation for operation get_adjoint_gradients
# Using cpu implementation for operation run
# Using cpu implementation for operation run_ss
# [CudaDevice(id=0), CudaDevice(id=1), CudaDevice(id=2), CudaDevice(id=3)]

# %%
# # %%
# st_config = {
#     "SourceCenter": 0.0,
#     "SourceHeight": 30.0,
#     "SourceWidth": 0.2,
#     "EdgeTemperature":0.5,
#     "EdgeDensity": 0.1,
#     "n0": 0.5,
# }
# # runner = MaNTA.Runner(st)

# # # %%
# solver_config = {
#     "OutputFilename": "stellarator2",
#     "Polynomial_degree": 3,
#     "Grid_size": 6,
#     "tau": 1.0, 
#     "Lower_boundary": 0.0,
#     "Upper_boundary": 1.0,
#     "Relative_tolerance": 0.01,
#     "delta_t": 0.01,
#     "restart": False,
#     "solveAdjoint": True, 
# }

# config = {
#     "Stellarator": st_config,
#     "Solver": solver_config,
# }

# points =  MaNTA.getNodes(solver_config["Lower_boundary"], solver_config["Upper_boundary"], solver_config["Grid_size"], solver_config["Polynomial_degree"])
# Density = lambda x : (st_config["n0"] - st_config["EdgeDensity"]) * (1 - x*x) + st_config["EdgeDensity"]

# yancc_wrapper = yancc_data.from_eq(points, Density=Density)

# st = StellaratorTransport(config, yancc_wrapper=yancc_wrapper)
# # field_ = st.field
# # grid_ = yancc_wrapper.grid
# vprim_ = st.vprime

# %%
import desc
from desc import set_device
set_device("gpu")

from desc.equilibrium import Equilibrium
from desc.geometry import FourierRZToroidalSurface
from desc.grid import Grid, LinearGrid
from desc.objectives import (
    AspectRatio,
    FixBoundaryR,
    FixBoundaryZ,
    FixCurrent,
    FixPsi,
    ForceBalance,
    LinearObjectiveFromUser,
    ObjectiveFunction,
    ObjectiveFromUser,
    RotationalTransform,
    Volume,
)
from desc.profiles import SplineProfile
from desc.plotting import (
    plot_grid,
    plot_boozer_modes,
    plot_boozer_surface,
    plot_qs_error,
    plot_boundaries,
    plot_boundary,
)
import equinox as eqx
import jax 
import jax.numpy as jnp

st_config = {
    "SourceCenter": 0.0,
    "SourceHeight": 80.0,
    "SourceWidth": 0.2,
    "EdgeTemperature":0.5,
    "EdgeDensity": 0.0,
    "n0": 0.5,
}

# # %%
solver_config = {
    "OutputFilename": "stellarator_opt",
    "Polynomial_degree": 4,
    "Grid_size": 4,
    "tau": 1.0, 
    "Lower_boundary": 0.0,
    "Upper_boundary": 1.0,
    "Relative_tolerance": 0.01,
    "Absolute_tolerance": [1e-4],
    "delta_t": 1e-4,
    "MinStepSize": 1e-8, 
    "SteadyStateTolerance": 1e-2,
    "restart": True,
    "solveAdjoint": True, 
}

config = {
    "Stellarator": st_config,
    "Solver": solver_config,
}

points =  MaNTA.getNodes(solver_config["Lower_boundary"], solver_config["Upper_boundary"], solver_config["Grid_size"], solver_config["Polynomial_degree"])

yancc_rho = jnp.array(points)
yancc_ntheta = 17
yancc_nzeta = 33

# to allow maximum flexibility to match manta, we use a spline with the same control points as manta \
# + axis and lcfs
# initial pressure is all zeros, can change this if desired
pressure_rho = jnp.concatenate([jnp.zeros(1), yancc_rho, jnp.ones(1)])
desc_pressure = SplineProfile(jnp.zeros_like(pressure_rho), pressure_rho)

eq = desc.examples.get("W7-X")

nx = 5
na = 43

# surf = eq_est.get_surface_at(rho=1)
# eq = Equilibrium(M=4, N=4, Psi=0.087, surface=surf, pressure=desc_pressure)
# eq = eq.solve(x_scale="ess")[0]
# # eq = eq.solve(x_scale="ess")[0]
# # # store initial equilibrium for comparison later
# eq_init = eq.copy()
# yancc_grid = desc.grid.LinearGrid(rho=yancc_rho, M=eq_init.M_grid, N = eq_init.N_grid, NFP=eq_init.NFP)
# points =  MaNTA.getNodes(solver_config["Lower_boundary"], solver_config["Upper_boundary"], solver_config["Grid_size"], solver_config["Polynomial_degree"])
# yancc_wrapper = yancc_data.from_eq(points, grid = yancc_grid,rho = yancc_rho, Density=Density, eq=eq_init, nt = yancc_ntheta, nz = yancc_nzeta)
yancc_wrapper = yancc_data.from_eq(points, eq=eq, nx=nx, na=na)

V0 = eq.compute("V")["V"]
# Out:
# /global/cfs/cdirs/mp217/eatocco/DESC/desc/__init__.py:94: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   from pynvml import (
# /global/cfs/cdirs/mp217/eatocco/DESC/desc/__init__.py:151: UserWarning: CUDA_VISIBLE_DEVICES= did not match any physical GPU (id=['0', '1', '2', '3']), falling back to CPU
#   warnings.warn(
# Initializing yancc wrapper
# yancc_wrapper initialized successfully.

# %%
# st = StellaratorTransport(config, yancc_wrapper=yancc_wrapper)

# st.run()

# %%
# import time
# import datetime

# tFinal = 1.0

# start = time.time()

# st.run()

# end = time.time()
# time_duration = datetime.timedelta(seconds=end-start)
# print("Elapsed time:")
# print(time_duration)

# %%
# import matplotlib.pyplot as plt
# u = st.getPressure()

# plt.plot(points, u)

# %%
# @eqx.filter_custom_jvp
# def Objective(fields, grid, yin):
#     yancc_wrapper = yancc_data.from_other(fields, grid, yin)

#     solver_config = {
#         "OutputFilename": "stellarator_opt",
#         "Polynomial_degree": 3,
#         "Grid_size": 6,
#         "tau": 100.0, 
#         "Lower_boundary": 0.0,
#         "Upper_boundary": 0.9,
#         "Relative_tolerance": 0.01,
#         "delta_t": 0.001,
#         "restart": True,
#         "solveAdjoint": True, 
#     }

#     config = {
#         "Stellarator": st_config,
#         "Solver": solver_config,
#     }
#     st = StellaratorTransport(config, yancc_wrapper=yancc_wrapper)
#     st.run()
#     G, G_p = st.runAdjointSolve()

#     pi = jnp.array(st.getPressure())

#     return G[0], pi

# @Objective.def_jvp
# def Objective_jvp(primals, tangents):
#     fields, grid, yin = primals
#     field_dot,_,_ = tangents
#     yancc_wrapper = yancc_data.from_other(fields, grid, yin)

#     solver_config = {
#         "OutputFilename": "stellarator_opt",
#         "Polynomial_degree": 3,
#         "Grid_size": 6,
#         "tau": 100.0, 
#         "Lower_boundary": 0.0,
#         "Upper_boundary": 0.9,
#         "Relative_tolerance": 0.01,
#         "delta_t": 0.001,
#         "restart": True,
#         "solveAdjoint": True, 
#     }

#     config = {
#         "Stellarator": st_config,
#         "Solver": solver_config,
#     }
#     st = StellaratorTransport(config, yancc_wrapper=yancc_wrapper)
#     st.run()
#     G, G_p = st.runAdjointSolve()
#     pi = jnp.array(st.getPressure())
    
#     field_dot_flatten,_ = jax.flatten_util.ravel_pytree(field_dot)

#     return (G[0], pi), (jnp.float32(jnp.dot(G_p.flatten(), field_dot_flatten)), None)

# %%
Objective = make_objective(config)
Objective_fd = make_objective_fd(config)
g = eqx.filter_grad(Objective, has_aux=True)
g_fd = eqx.filter_grad(Objective_fd, has_aux=True)
fields = yancc_wrapper.fields
grid = yancc_wrapper.grid

Vprime = yancc_wrapper.Vprim

g_fd_out = g_fd(fields, grid, Vprime)
g_out = g(fields, grid, Vprime)

# print(g(fields, grid, Vprime))
# Out:
# yancc_wrapper initialized successfully.
# configuring
# Successfully created StellaratorTransport object
# INFO: Using default value for configuration option RestartFile
# Total HDG degrees of freedom 65
# INFO: Using default value for configuration option tZero
# INFO: Using default value for configuration option OutputPoints
# INFO: Using default value for configuration option useCalcIC
# INFO: Using default value for configuration option WriteOutput
# Configuration done.
# Setting initial conditions
# Residual norm at t = 0: inf
# Residual norm at t = 0: 0
# Residual norm at t = 0: 9.44176e+87
# Residual norm at t = 0: 0.0663919
# Number of Residual Evaluations due to IDACalcIC 3
# Residual norm at t = 0: 0.438831
# Residual norm at t = 0.0001: 9.44176e+87
# Residual norm at t = 0.0001: 1.00662
# Writing output at 0.0001 ( 1 timesteps )
# Residual norm at t = 0.0001: 0.436691
#  dy/dt norm inferred from lambdas is 0.845706
# Steady State achieved at time t = 0.0001
# Total Number of Timesteps             :1
# Total Number of Residual Evaluations  :5
# Total Number of Jacobian Computations :3
# Computing adjoints
# INFO: Computing adjoints for 5720 parameters
# Successfully computed dgdp
# 20
# 5720
# Done.
# yancc_wrapper initialized successfully.
# configuring
# Successfully created StellaratorTransport object
# INFO: Using default value for configuration option RestartFile
# Total HDG degrees of freedom 65
# INFO: Using default value for configuration option tZero
# INFO: Using default value for configuration option OutputPoints
# INFO: Using default value for configuration option useCalcIC
# INFO: Using default value for configuration option WriteOutput
# Configuration done.
# Setting initial conditions
# Residual norm at t = 0: inf
# Residual norm at t = 0: 0
# Residual norm at t = 0: 0
# Residual norm at t = 0: 0.0661552
# Number of Residual Evaluations due to IDACalcIC 3
# Residual norm at t = 0: 0.438042
# Residual norm at t = 0.0001: 9.36819e+87
# Residual norm at t = 0.0001: 0.993386
# Writing output at 0.0001 ( 1 timesteps )
# Residual norm at t = 0.0001: 0.436053
#  dy/dt norm inferred from lambdas is 0.838142
# Steady State achieved at time t = 0.0001
# Total Number of Timesteps             :1
# Total Number of Residual Evaluations  :5
# Total Number of Jacobian Computations :3
# Computing adjoints
# INFO: Computing adjoints for 5720 parameters
# Successfully computed dgdp
# 20
# 5720
# Done.
# yancc_wrapper initialized successfully.
# configuring
# Successfully created StellaratorTransport object
# INFO: Using default value for configuration option RestartFile
# Total HDG degrees of freedom 65
# INFO: Using default value for configuration option tZero
# INFO: Using default value for configuration option OutputPoints
# INFO: Using default value for configuration option useCalcIC
# INFO: Using default value for configuration option WriteOutput
# Configuration done.
# Setting initial conditions
# ---------------------------------------------------------------------------
# JaxRuntimeError                           Traceback (most recent call last)
# Cell In[15], line 11
#       8 Vprime = yancc_wrapper.Vprim
#      10 g_out = g(fields, grid, Vprime)
# ---> 11 g_fd_out = g_fd(fields, grid, Vprime)
#      12 # print(g(fields, grid, Vprime))
#
# File ~/.conda/envs/desc-env/lib/python3.12/site-packages/equinox/_ad.py:88, in _GradWrapper.__call__(self, *args, **kwargs)
#      87 def __call__(self, /, *args, **kwargs):
# ---> 88     value, grad = self._fun_value_and_grad(*args, **kwargs)
#      89     if self._has_aux:
#      90         _, aux = value
#
# File ~/.conda/envs/desc-env/lib/python3.12/site-packages/equinox/_ad.py:71, in _ValueAndGradWrapper.__call__(self, *args, **kwargs)
#      69 x, *args = args
#      70 diff_x, nondiff_x = partition(x, is_inexact_array)
# ---> 71 return fun_value_and_grad(diff_x, nondiff_x, *args, **kwargs)
#
#     [... skipping hidden 22 frame]
#
# File /global/u2/e/eatocco/projects/MaNTA/python/Objective.py:35, in _objective_base_jvp(primals, tangents)
#      33 st = StellaratorTransport(config, yancc_wrapper=yin)
#      34 st.run()
# ---> 35 G, G_p = st.getAdjointGradients()
#      37 pi = jnp.array(st.getPressure())
#      39 return G[0], G_p, pi
#
# File /global/u2/e/eatocco/projects/MaNTA/python/Objective.py:33, in f(fields_in)
#      32 def StellaratorFun(config, yin):
# ---> 33     st = StellaratorTransport(config, yancc_wrapper=yin)
#      34     st.run()
#      35     G, G_p = st.getAdjointGradients()
#
# File /global/u2/e/eatocco/projects/MaNTA/python/Objective.py:5, in StellaratorFun(config, yin)
#       3 import equinox as eqx
#       4 import functools
# ----> 5 from Stellarator import StellaratorTransport
#       6 import yancc
#       7 from yancc_wrapper import yancc_data
#
# File /global/u2/e/eatocco/projects/MaNTA/python/Stellarator.py:178, in StellaratorTransport.run(self, tFinal)
#     176     self.runner.Run(tFinal)
#     177 else:
# --> 178     self.runner.Run_ss()
#
# File /global/u2/e/eatocco/projects/MaNTA/python/FFIRunner.py:75, in FFIRunner.Run_ss(self)
#      73 def Run_ss(self):
#      74     with jax.default_device(cpu_device):
# ---> 75         jax.ffi.ffi_call(ffi_ops["run_ss"], [],  has_side_effect=True)(obj=self.get_address())
#
# File ~/.conda/envs/desc-env/lib/python3.12/site-packages/jax/_src/ffi.py:563, in ffi_call.<locals>.wrapped(*args, **kwargs)
#     561     static_input_output_aliases.append((i_idx, o_idx))
#     562 args = core.standard_insert_pvary(*args)
# --> 563 results = ffi_call_p.bind(
#     564     *args,
#     565     result_avals=result_avals,
#     566     vmap_method=vmap_method,
#     567     target_name=target_name,
#     568     has_side_effect=has_side_effect,
#     569     input_layouts=static_input_layouts,
#     570     output_layouts=static_output_layouts,
#     571     input_output_aliases=tuple(static_input_output_aliases),
#     572     custom_call_api_version=custom_call_api_version,
#     573     legacy_backend_config=legacy_backend_config,
#     574     attributes=_wrap_kwargs_hashable(kwargs),
#     575 )
#     576 if multiple_results:
#     577   if isinstance(result_shape_dtypes, tuple):
#
#     [... skipping hidden 12 frame]
#
# File ~/.conda/envs/desc-env/lib/python3.12/site-packages/jax/_src/interpreters/pxla.py:1354, in ExecuteReplicated.__call__(self, *args)
#    1351 if (self.ordered_effects or self.has_unordered_effects
#    1352     or self.has_host_callbacks):
#    1353   input_bufs = self._add_tokens_to_inputs(input_bufs)
# -> 1354   results = self.xla_executable.execute_sharded(input_bufs, with_tokens=True)
#    1356   result_token_bufs = results.consume_with_handlers(
#    1357       [lambda xs: xs] * len(self.ordered_effects), strict=False)
#    1358   sharded_runtime_token = results.consume_token()
#
# JaxRuntimeError: UNKNOWN: XLA FFI call failed: Error occurred when trying to calculate SigmaFn: UnexpectedTracerError: Encountered an unexpected tracer. A function transformed by JAX had a side effect, allowing for a reference to an intermediate value with type float64[20] wrapped in a JaxprTracer to escape the scope of the transformation.
# JAX transformations require that functions explicitly return their outputs, and disallow saving intermediate values to global state.
# To catch the leak earlier, try setting the environment variable JAX_CHECK_TRACER_LEAKS or using the `jax.checking_leaks` context manager.
# See https://docs.jax.dev/en/latest/errors.html#jax.errors.UnexpectedTracerError
#
# At:
#   /global/homes/e/eatocco/.conda/envs/desc-env/lib/python3.12/site-packages/jax/_src/core.py(1204): check_eval_args
#   /global/homes/e/eatocco/.conda/envs/desc-env/lib/python3.12/site-packages/jax/_src/core.py(1216): process_primitive
#   /global/homes/e/eatocco/.conda/envs/desc-env/lib/python3.12/site-packages/jax/_src/core.py(656): bind_with_trace
#   /global/homes/e/eatocco/.conda/envs/desc-env/lib/python3.12/site-packages/jax/_src/core.py(650): bind
#   /global/homes/e/eatocco/.conda/envs/desc-env/lib/python3.12/site-packages/jax/_src/pjit.py(1444): _pjit_batcher
#   /global/homes/e/eatocco/.conda/envs/desc-env/lib/python3.12/site-packages/jax/_src/interpreters/batching.py(260): process_primitive
#   /global/homes/e/eatocco/.conda/envs/desc-env/lib/python3.12/site-packages/jax/_src/core.py(656): bind_with_trace
#   /global/homes/e/eatocco/.conda/envs/desc-env/lib/python3.12/site-packages/jax/_src/core.py(650): bind
#   /global/homes/e/eatocco/.conda/envs/desc-env/lib/python3.12/site-packages/jax/_src/pjit.py(170): _run_python_pjit
#   /global/homes/e/eatocco/.conda/envs/desc-env/lib/python3.12/site-packages/jax/_src/pjit.py(256): cache_miss
#   /global/homes/e/eatocco/.conda/envs/desc-env/lib/python3.12/site-packages/jax/_src/traceback_util.py(200): reraise_with_filtered_traceback
#   /global/homes/e/eatocco/.conda/envs/desc-env/lib/python3.12/site-packages/equinox/_jit.py(293): _call
#   /global/homes/e/eatocco/.conda/envs/desc-env/lib/python3.12/site-packages/equinox/_jit.py(210): __call__
#   /global/u2/e/eatocco/projects/MaNTA/python/Stellarator.py(262): sigma
#   /global/homes/e/eatocco/.conda/envs/desc-env/lib/python3.12/site-packages/equinox/_vmap_pmap.py(154): _fun_wrapper
#   /global/homes/e/eatocco/.conda/envs/desc-env/lib/python3.12/site-packages/jax/_src/interpreters/batching.py(120): flatten_fun_for_vmap
#   /global/homes/e/eatocco/.conda/envs/desc-env/lib/python3.12/site-packages/jax/_src/interpreters/batching.py(394): _batch_inner
#   /global/homes/e/eatocco/.conda/envs/desc-env/lib/python3.12/site-packages/jax/_src/interpreters/batching.py(375): _batch_outer
#   /global/homes/e/eatocco/.conda/envs/desc-env/lib/python3.12/site-packages/jax/_src/linear_util.py(212): call_wrapped
#   /global/homes/e/eatocco/.conda/envs/desc-env/lib/python3.12/site-packages/jax/_src/api.py(1222): vmap_f
#   /global/homes/e/eatocco/.conda/envs/desc-env/lib/python3.12/site-packages/jax/_src/traceback_util.py(200): reraise_with_filtered_traceback
#   /global/homes/e/eatocco/.conda/envs/desc-env/lib/python3.12/site-packages/equinox/_vmap_pmap.py(169): __call__
#   /global/u2/e/eatocco/projects/MaNTA/python/Stellarator.py(197): SigmaFn_v
#   /global/u2/e/eatocco/projects/MaNTA/python/Stellarator.py(50): _wrap_shard
#   /global/u2/e/eatocco/projects/MaNTA/python/Stellarator.py(52): wrapper
#   /global/homes/e/eatocco/.conda/envs/desc-env/lib/python3.12/site-packages/jax/_src/interpreters/pxla.py(1354): __call__
#   /global/homes/e/eatocco/.conda/envs/desc-env/lib/python3.12/site-packages/jax/_src/profiler.py(384): wrapper
#   /global/homes/e/eatocco/.conda/envs/desc-env/lib/python3.12/site-packages/jax/_src/pjit.py(1182): _pjit_call_impl_python
#   /global/homes/e/eatocco/.conda/envs/desc-env/lib/python3.12/site-packages/jax/_src/pjit.py(141): _run_python_pjit
#   /global/homes/e/eatocco/.conda/envs/desc-env/lib/python3.12/site-packages/jax/_src/pjit.py(256): cache_miss
#   /global/homes/e/eatocco/.conda/envs/desc-env/lib/python3.12/site-packages/jax/_src/traceback_util.py(196): reraise_with_filtered_traceback
#   /global/homes/e/eatocco/.conda/envs/desc-env/lib/python3.12/site-packages/jax/_src/dispatch.py(91): apply_primitive
#   /global/homes/e/eatocco/.conda/envs/desc-env/lib/python3.12/site-packages/jax/_src/core.py(1217): process_primitive
#   /global/homes/e/eatocco/.conda/envs/desc-env/lib/python3.12/site-packages/jax/_src/core.py(656): bind_with_trace
#   /global/homes/e/eatocco/.conda/envs/desc-env/lib/python3.12/site-packages/jax/_src/interpreters/partial_eval.py(195): default_process_primitive
#   /global/homes/e/eatocco/.conda/envs/desc-env/lib/python3.12/site-packages/jax/_src/interpreters/partial_eval.py(186): process_primitive
#   /global/homes/e/eatocco/.conda/envs/desc-env/lib/python3.12/site-packages/jax/_src/core.py(656): bind_with_trace
#   /global/homes/e/eatocco/.conda/envs/desc-env/lib/python3.12/site-packages/jax/_src/core.py(648): bind
#   /global/homes/e/eatocco/.conda/envs/desc-env/lib/python3.12/site-packages/jax/_src/ffi.py(563): wrapped
#   /global/u2/e/eatocco/projects/MaNTA/python/FFIRunner.py(75): Run_ss
#   /global/u2/e/eatocco/projects/MaNTA/python/Stellarator.py(178): run
#   /global/u2/e/eatocco/projects/MaNTA/python/Objective.py(5): StellaratorFun
#   /global/u2/e/eatocco/projects/MaNTA/python/Objective.py(33): f
#   /global/u2/e/eatocco/projects/MaNTA/python/Objective.py(35): _objective_base_jvp
#   /global/homes/e/eatocco/.conda/envs/desc-env/lib/python3.12/site-packages/equinox/_ad.py(806): fn_jvp_wrapper
#   /global/homes/e/eatocco/.conda/envs/desc-env/lib/python3.12/site-packages/jax/_src/api_util.py(235): _prepend_static_args
#   /global/homes/e/eatocco/.conda/envs/desc-env/lib/python3.12/site-packages/jax/_src/custom_derivatives.py(313): _flatten_jvp
#   /global/homes/e/eatocco/.conda/envs/desc-env/lib/python3.12/site-packages/jax/_src/linear_util.py(212): call_wrapped
#   /global/homes/e/eatocco/.conda/envs/desc-env/lib/python3.12/site-packages/jax/_src/interpreters/ad.py(899): _f_jvp
#   /global/homes/e/eatocco/.conda/envs/desc-env/lib/python3.12/site-packages/jax/_src/linear_util.py(212): call_wrapped
#   /global/homes/e/eatocco/.conda/envs/desc-env/lib/python3.12/site-packages/jax/_src/interpreters/ad.py(1088): linearize_from_jvp
#   /global/homes/e/eatocco/.conda/envs/desc-env/lib/python3.12/site-packages/jax/_src/interpreters/ad.py(906): process_custom_jvp_call
#   /global/homes/e/eatocco/.conda/envs/desc-env/lib/python3.12/site-packages/jax/_src/custom_derivatives.py(393): bind_with_trace
#   /global/homes/e/eatocco/.conda/envs/desc-env/lib/python3.12/site-packages/jax/_src/core.py(648): bind
#   /global/homes/e/eatocco/.conda/envs/desc-env/lib/python3.12/site-packages/jax/_src/custom_derivatives.py(303): __call__
#   /global/homes/e/eatocco/.conda/envs/desc-env/lib/python3.12/site-packages/jax/_src/traceback_util.py(196): reraise_with_filtered_traceback
#   /global/homes/e/eatocco/.conda/envs/desc-env/lib/python3.12/site-packages/equinox/_ad.py(819): __call__
#   /global/homes/e/eatocco/.conda/envs/desc-env/lib/python3.12/site-packages/equinox/_ad.py(54): fun_value_and_grad
#   /global/homes/e/eatocco/.conda/envs/desc-env/lib/python3.12/site-packages/jax/_src/api_util.py(264): _argnums_partial
#   /global/homes/e/eatocco/.conda/envs/desc-env/lib/python3.12/site-packages/jax/_src/api_util.py(107): flatten_fun_nokwargs2
#   /global/homes/e/eatocco/.conda/envs/desc-env/lib/python3.12/site-packages/jax/_src/linear_util.py(212): call_wrapped
#   /global/homes/e/eatocco/.conda/envs/desc-env/lib/python3.12/site-packages/jax/_src/interpreters/ad.py(302): direct_linearize
#   /global/homes/e/eatocco/.conda/envs/desc-env/lib/python3.12/site-packages/jax/_src/interpreters/ad.py(331): linearize
#   /global/homes/e/eatocco/.conda/envs/desc-env/lib/python3.12/site-packages/jax/_src/api.py(2218): _vjp
#   /global/homes/e/eatocco/.conda/envs/desc-env/lib/python3.12/site-packages/jax/_src/api.py(543): value_and_grad_f
#   /global/homes/e/eatocco/.conda/envs/desc-env/lib/python3.12/site-packages/jax/_src/traceback_util.py(196): reraise_with_filtered_traceback
#   /global/homes/e/eatocco/.conda/envs/desc-env/lib/python3.12/site-packages/equinox/_ad.py(71): __call__
#   /global/homes/e/eatocco/.conda/envs/desc-env/lib/python3.12/site-packages/equinox/_ad.py(88): __call__
#   /tmp/ipykernel_992943/748507502.py(11): <module>
#   /global/homes/e/eatocco/.conda/envs/desc-env/lib/python3.12/site-packages/IPython/core/interactiveshell.py(3701): run_code
#   /global/homes/e/eatocco/.conda/envs/desc-env/lib/python3.12/site-packages/IPython/core/interactiveshell.py(3641): run_ast_nodes
#   /global/homes/e/eatocco/.conda/envs/desc-env/lib/python3.12/site-packages/IPython/core/interactiveshell.py(3400): run_cell_async
#   /global/homes/e/eatocco/.conda/envs/desc-env/lib/python3.12/site-packages/IPython/core/async_helpers.py(128): _pseudo_sync_runner
#   /global/homes/e/eatocco/.conda/envs/desc-env/lib/python3.12/site-packages/IPython/core/interactiveshell.py(3178): _run_cell
#   /global/homes/e/eatocco/.conda/envs/desc-env/lib/python3.12/site-packages/IPython/core/interactiveshell.py(3123): run_cell
#   /global/homes/e/eatocco/.conda/envs/desc-env/lib/python3.12/site-packages/ipykernel/zmqshell.py(663): run_cell
#   /global/homes/e/eatocco/.conda/envs/desc-env/lib/python3.12/site-packages/ipykernel/ipkernel.py(464): do_execute
#   /global/homes/e/eatocco/.conda/envs/desc-env/lib/python3.12/site-packages/ipykernel/kernelbase.py(834): execute_request
#   /global/homes/e/eatocco/.conda/envs/desc-env/lib/python3.12/site-packages/ipykernel/ipkernel.py(372): execute_request
#   /global/homes/e/eatocco/.conda/envs/desc-env/lib/python3.12/site-packages/ipykernel/kernelbase.py(478): dispatch_shell
#   /global/homes/e/eatocco/.conda/envs/desc-env/lib/python3.12/site-packages/ipykernel/kernelbase.py(621): shell_main
#   /global/homes/e/eatocco/.conda/envs/desc-env/lib/python3.12/asyncio/events.py(88): _run
#   /global/homes/e/eatocco/.conda/envs/desc-env/lib/python3.12/asyncio/base_events.py(1999): _run_once
#   /global/homes/e/eatocco/.conda/envs/desc-env/lib/python3.12/asyncio/base_events.py(645): run_forever
#   /global/homes/e/eatocco/.conda/envs/desc-env/lib/python3.12/site-packages/tornado/platform/asyncio.py(211): start
#   /global/homes/e/eatocco/.conda/envs/desc-env/lib/python3.12/site-packages/ipykernel/kernelapp.py(758): start
#   /global/homes/e/eatocco/.conda/envs/desc-env/lib/python3.12/site-packages/traitlets/config/application.py(1075): launch_instance
#   /global/homes/e/eatocco/.conda/envs/desc-env/lib/python3.12/site-packages/ipykernel_launcher.py(18): <module>
#   /global/homes/e/eatocco/.conda/envs/desc-env/lib/python3.12/runpy.py(88): _run_code
#   /global/homes/e/eatocco/.conda/envs/desc-env/lib/python3.12/runpy.py(198): _run_module_as_main

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
print(g_out)
field_grad = g_out[0]
ax.plot(field_grad.psi_r, label="adjoints")
# ax.plot(g_fd_out.Bmag_fsa, label="finite_differences")

ax.legend()

fig, ax = plt.subplots()

ax.plot(jnp.sum(field_grad.bdotgradB, axis=0), label="adjoints")
# ax.plot(g_fd_out.sqrtg, label="finite_differences")

ax.legend()
# Out:
# (Field(
#   rho=f64[20],
#   theta=f64[20,17],
#   zeta=f64[20,33],
#   wtheta=f64[20,17],
#   wzeta=f64[20,33],
#   B_sup_t=f64[20,17,33],
#   B_sup_z=f64[20,17,33],
#   B_sub_t=f64[20,17,33],
#   B_sub_z=f64[20,17,33],
#   sqrtg=f64[20,17,33],
#   Bmag=f64[20,17,33],
#   bdotgradB=f64[20,17,33],
#   BxgradrhodotgradB=f64[20,17,33],
#   dBdt=f64[20,17,33],
#   dBdz=f64[20,17,33],
#   Bmag_fsa=f64[20],
#   B2mag_fsa=f64[20],
#   psi_r=f64[20],
#   psi_rho=f64[20],
#   Psi=f64[20],
#   R_major=f64[20],
#   a_minor=f64[20],
#   iota=f64[20],
#   B0=f64[20],
#   ntheta=17,
#   nzeta=33,
#   NFP=None
# ), Array([8746.009   , 8448.53    , 7716.6055  , 6820.848   , 6251.807   ,
#        6080.5835  , 5499.153   , 4608.3726  , 3840.4075  , 3426.506   ,
#        3325.685   , 2965.951   , 2443.9536  , 1956.5881  , 1662.3142  ,
#        1582.3457  , 1287.2576  ,  807.6962  ,  330.58353 ,   39.467255],      dtype=float32))
