# %%
# %reload_ext autoreload
# %autoreload 2 

import MaNTA

from Stellarator import StellaratorTransport
# Out:
# Using cache directory: /global/cfs/cdirs/mp217/eatocco/__pycache__
# [CudaDevice(id=0), CudaDevice(id=1), CudaDevice(id=2), CudaDevice(id=3)]

# %%
st_config = {
    "SourceCenter": 0.0,
    "SourceHeight": 30.0,
    "SourceWidth": 0.2,
    "EdgeTemperature":0.5,
    "EdgeDensity": 0.1,
    "n0": 0.5,
}

st = StellaratorTransport(st_config)
runner = MaNTA.Runner(st)
# Out:
# Initializing yancc wrapper with parameters:
#   nx=5, na=43, nt=17, nz=33
# yancc_wrapper initialized successfully.
# computing field
# INFO: Using default value for configuration option RestartFile
# Total HDG degrees of freedom 79
# INFO: Using default value for configuration option Absolute_tolerance
# INFO: Using default value for configuration option tZero
# INFO: Using default value for configuration option MinStepSize
# INFO: Using default value for configuration option OutputPoints
# INFO: Using default value for configuration option SteadyStateTolerance
# INFO: Using default value for configuration option WriteOutput
# Setting initial conditions
# Evaluating residual at time t=0
# Updating Jacobian at t=0
# Evaluating residual at time t=0
# Updating Jacobian at t=0
# Number of Residual Evaluations due to IDACalcIC 2
# Configuration done.
# 5721
# Successfully created StellaratorTransport object

# %%
tFinal = 1.0
import time
import datetime

start = time.time()
st.run()

end = time.time()
time_duration = datetime.timedelta(seconds=end-start)
print("Elapsed time:")
print(time_duration)
# Out:
# Evaluating residual at time t=1e-06
# Updating Jacobian at t=1e-06
# Evaluating residual at time t=2e-06
# Evaluating residual at time t=4e-06
# Evaluating residual at time t=8e-06
# Updating Jacobian at t=8e-06
# Evaluating residual at time t=1.6e-05
# Updating Jacobian at t=1.6e-05
# Evaluating residual at time t=3.2e-05
# Updating Jacobian at t=3.2e-05
# Evaluating residual at time t=6.4e-05
# Updating Jacobian at t=6.4e-05
# Evaluating residual at time t=0.000128
# Updating Jacobian at t=0.000128
# Evaluating residual at time t=0.000256
# Updating Jacobian at t=0.000256
# Evaluating residual at time t=0.000512
# Updating Jacobian at t=0.000512
# Evaluating residual at time t=0.001024
# Updating Jacobian at t=0.001024
# Writing output at 0.001 ( 11 timesteps )
# Steady State achieved at time t = 0.001
# Total Number of Timesteps             :11
# Total Number of Residual Evaluations  :13
# Total Number of Jacobian Computations :11
# Done.
#
# 0:03:09.815195

# %%
import matplotlib.pyplot as plt

# %%
G, G_p = st.runAdjointSolve()
print("Stored energy: " + str(G))

plt.plot(G_p['G_p'])
print(G_p)
# Out:
# Computing adjoints
# VmapTracer(aval=float64[], batched=float64[24])
# INFO: Computing adjoints for 137280 parameters
# (5720, 24)
# computing dGFndp
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~/.conda/envs/desc-env/lib/python3.12/site-packages/jax/_src/api.py:1265, in _mapped_axis_size.<locals>._get_axis_size(name, shape, axis)
#    1264 try:
# -> 1265   return shape[axis]
#    1266 except (IndexError, TypeError) as e:
#
# IndexError: tuple index out of range
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 G, G_p = st.runAdjointSolve()
#       2 print("Stored energy: " + str(G))
#       4 plt.plot(G_p['G_p'])
#
# File /global/u2/e/eatocco/projects/MaNTA/python/Stellarator.py:132, in StellaratorTransport.runAdjointSolve(self, eq)
#     130     field, vprime = self.yancc_wrapper.compute_field(self.points)
#     131     self.adjointProblem.setField(field, vprime)
# --> 132 G, G_p = self.runner.runAdjointSolve()
#     133 return G, G_p
#
# File /global/u2/e/eatocco/projects/MaNTA/python/Stellarator.py:311, in StellaratorAdjointProblem.dgFndp(self, i, state, x)
#     309 fgrad = jax.grad(self.g[i], argnums=2) #eqx.filter_grad(lambda field: self.g[i](state, x, field, self.params))
#     310 fgrad_vmap = jax.vmap(fgrad, in_axes=({"Variable": 0, "Derivative": 0, "Flux": 0, "Aux": 0, "Scalars": None}, 0, 0, None))
# --> 311 grad, self.unravel = jax.flatten_util.ravel_pytree(fgrad_vmap(state, x, self.field, self.params))
#     312 # out = jnp.pad(g, pad_width=(0, self.np_boundary), mode='constant', constant_values=0)
#     313 return grad
#
#     [... skipping hidden 5 frame]
#
# File ~/.conda/envs/desc-env/lib/python3.12/site-packages/jax/_src/api.py:1269, in _mapped_axis_size.<locals>._get_axis_size(name, shape, axis)
#    1267 min_rank = axis + 1 if axis >= 0 else -axis
#    1268 # TODO(mattjj): better error message here
# -> 1269 raise ValueError(
#    1270     f"{name} was requested to map its argument along axis {axis}, "
#    1271     f"which implies that its rank should be at least {min_rank}, "
#    1272     f"but is only {len(shape)} (its shape is {shape})") from e
#
# ValueError: vmap was requested to map its argument along axis 0, which implies that its rank should be at least 1, but is only 0 (its shape is ())
